# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts='140.137.41.81', port=9200)

# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import metrics
import operator
import math

# %%
#建立ling-林郁芮01text資料庫

from elasticsearch import Elasticsearch
import json

def create_index(es):
    body = dict()
    body['settings'] = get_setting()
    body['mappings'] = get_mappings()
    print(json.dumps(body)) #可以用json.dumps輸出來看格式有沒又包錯
    es.indices.create(index='ling-林郁芮01text', body=body)

def get_setting():
    settings = {
        "index": {
            "number_of_shards": 3,
            "number_of_replicas": 2
        }
    }
    return settings

def get_mappings():
    mappings = {
        "properties": {
            #編號
            "Number": {
                "type": "integer"
            },
            #編號
            "name": {
                "type": "keyword"
            },
            #影片類別
            "video type": {
                "type": "keyword"
            },
            #平均
            "average": {
                "type": "float"
            },
            #一階差
            "first order difference": {
                "type": "float"
            },
            #二階差
            "second order difference": {
                "type": "float"
            },
            #最大心率
            "max heart": {
                "type": "integer"
            },
            #最小心率
            "min heart": {
                "type": "integer"
            },
            #心率變化範圍
            "max to min scope heart": {
                "type": "integer"
            },
            #資訊熵
            "entropy of information": {
                "type": "float"
            },
            #均方根
            "root mean square": {
                "type": "float"
            },
            #標準化均值
            "standardize average": {
                "type": "float"
            }
        }
    }
    return mappings

if __name__ == "__main__":
    es = Elasticsearch(hosts='140.137.41.81', port=9200)
    create_index(es)
# Out:
# {"settings": {"index": {"number_of_shards": 3, "number_of_replicas": 2}}, "mappings": {"properties": {"Number": {"type": "integer"}, "name": {"type": "keyword"}, "video type": {"type": "keyword"}, "average": {"type": "float"}, "first order difference": {"type": "float"}, "second order difference": {"type": "float"}, "max heart": {"type": "integer"}, "min heart": {"type": "integer"}, "max to min scope heart": {"type": "integer"}, "entropy of information": {"type": "float"}, "root mean square": {"type": "float"}, "standardize average": {"type": "float"}}}}

# %%
#將ling-林郁芮數據01的1st進行計算並且將結果傳送到ling-林郁芮01text資料庫

from elasticsearch import Elasticsearch
import json

# 正常(feel=naturl)心率取5個為一組
SamplesStartA = 0
SamplesStopA = 50

#A視頻(feel=happy)心率取5個為一組
SamplesStartB = 0
SamplesStopB = 50

#C視頻(feel=sad)心率取5個為一組
SamplesStartC = 0
SamplesStopC = 50

name="林郁芮"

arra=[0]*5
x=0
arrb=[0]*5
y=0
arrd=[0]*5
z=0

A=5
B=5
D=5

for n in range(0,25): #迴圈取[a1,a11,a21,...],[a2,a22,a33...],[a3,a23,a33...]...共取25組
    arra=[0]*5
    x=0
    arrb=[0]*5
    y=0
    arrd=[0]*5
    z=0
    A=5
    B=5
    D=5
    SamplesStartA+=1
    SamplesStopA+=1
    SamplesStartB+=1
    SamplesStopB+=1
    SamplesStartC+=1
    SamplesStopC+=1
    for m in range(SamplesStartA,SamplesStopA,10):  #迴圈取a1,a11,a21,a31,a41...一組取5個
        def get_queryA():
            queryA = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "name": "林郁芮"
                        }
                    },
                        {
                        "term": {
                            "feel": "natural"
                        }
                    },
                    {
                        "term": {
                            "time": m
                        }
                    },
                        {
                        "term": {
                            "trial": "1st"
                        }
                    }]
                }
            }
        }
            return queryA
        if __name__ == "__main__":
            es = Elasticsearch(hosts='140.137.41.81', port=9200)
            queryA = get_queryA()
            resultA = es.search(index='ling-林郁芮數據01', body=queryA)
            resultaa=json.dumps(resultA, ensure_ascii=False)
            resultPulseA=json.loads(resultaa)
            print("A")
            print(resultPulseA['hits']['hits'][0]['_source']['pulse'])
            aa=resultPulseA['hits']['hits'][0]['_source']['pulse']
            arra[x]=aa
            if x==4:
                print(arra)
                x-=4
            else:
                x+=1
    for p in range(SamplesStartB,SamplesStopB,10):  #迴圈取A視頻心率a1,a11,a21,a31,a41...一組取5個
        def get_queryB():
            queryB = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "name": "林郁芮"
                        }
                    },
                        {
                        "term": {
                            "feel": "happy"
                        }
                    },
                    {
                        "term": {
                            "time": p
                        }
                    },
                        {
                        "term": {
                            "trial": "1st"
                        }
                    }]
                }
            }
        }
            return queryB
        if __name__ == "__main__":
            es = Elasticsearch(hosts='140.137.41.81', port=9200)
            queryB = get_queryB()
            resultB = es.search(index='ling-林郁芮數據01', body=queryB)
            resultbb=json.dumps(resultB, ensure_ascii=False)
            resultPulseB=json.loads(resultbb)
            print("B")
            print(resultPulseB['hits']['hits'][0]['_source']['pulse'])
            bb=resultPulseB['hits']['hits'][0]['_source']['pulse']
            arrb[y]=bb
            if y==4:
                print(arrb)
                y-=4
            else:
                y+=1
    for q in range(SamplesStartC,SamplesStopC,10):     #迴圈取C視頻心率a1,a11,a21,a31,a41...一組取5個
        def get_queryC():
            queryC = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "name": "林郁芮"
                        }
                    },
                        {
                        "term": {
                            "feel": "sad"
                        }
                    },
                    {
                        "term": {
                            "time": q
                        }
                    },
                        {
                        "term": {
                            "trial": "1st"
                        }
                    }]
                }
            }
        }
            return queryC
        if __name__ == "__main__":
            es = Elasticsearch(hosts='140.137.41.81', port=9200)
            queryC = get_queryC()
            resultC = es.search(index='ling-林郁芮數據01', body=queryC)
            resultcc=json.dumps(resultC, ensure_ascii=False)
            resultPulseC=json.loads(resultcc)
            print("C")
            print(resultPulseC['hits']['hits'][0]['_source']['pulse'])
            cc=resultPulseC['hits']['hits'][0]['_source']['pulse']
            arrd[z]=cc
            if z==4:
                print(arrd)
                z-=4
            else:
                z+=1
    #正常心率平均
    ave = 0.0
    for i in range(0,A):
        ave+=arra[i]
    ave = ave/A

    print("A視頻心率特徵 :")

    #平均
    aveB = 0.0
    for i in range(0,B):
        aveB +=arrb[i]
    aveB = aveB/B
    print("平均: ",aveB)

    #DiffB1 一階差的平均值
    diffB1 = 0.0
    meanB1 = 0.0
    #X[n-1]-X[n]的總和
    for i in range(0,(B-1)):
        meanB1+=abs(arrb[i+1]-arrb[i])
    diffB1 = meanB1/(B-1)
    print("一階差: ",diffB1)

    #DiffB2 二階差的平均值
    diffB2 = 0.0
    meanB2 = 0.0
    #X[n+2]-X[n]的總和
    for i in range(0,(B-2)):
        meanB2 += abs(arrb[i+2]-arrb[i])
    diffB2 = meanB2/(B-2)
    print("二階差: ",diffB2)

    #range 心率變化範圍
    scopeB = 0
    scopemaxB = 0
    scopeminB = 110
    for i in range(0,B):
        #求最大心率
        if arrb[i]>scopemaxB:
            scopemaxB = arrb[i]
        if arrb[i]<scopeminB:
            scopeminB = arrb[i]
    scopeB = scopemaxB-scopeminB
    print("最大心率: ",scopemaxB)
    print("最小心率: ",scopeminB)
    print("心率變化範圍: ",scopeB)

    #H(X)資訊熵
    x = 0
    HB = 0
    arrpb = [0.0]*B
    for i in range(0,B):
        x=0 #初值為0
        #心率出現次數
        for j in range(0,B):
            if arrb[i]==arrb[j]:
                x+=1
        #p[i]機率
        arrpb[i] = x*1.0/B
    for k in range(0,B):
        HB += -arrpb[k]*math.log(arrpb[k],2)
    print("資訊熵: ",HB)

    #Radrm 均方根
    radrmB = 0.0   
    meanrB = 0.0
    #相鄰值平方差的總和
    for i in range(0,(B-1)):
        radrmB += pow(arrb[i+1]-arrb[i],2)
    meanrB = radrmB/B
    print("均方根: ",meanrB)

    #標準化均值
    arrbb=[0.0]*B
    aveb = 0.0
    for i in range(0,B):
        arrbb[i] = arrb[i]-ave
        aveb += arrbb[i]
    aveb = aveb/B
    print("標準化均值: ",aveb)
    def load_datas():
        datas = list()
        datas.append(
        {
            #匯入編號
            "Number": int(n),
            #匯入名字
            "name": name,
            #匯入影片類別
            "video type": "A",
            #匯入平均
            "average": float(aveB),
            #匯入一階差
            "first order difference":float(diffB1),
            #匯入二階差
            "second order difference":float(diffB2),
            #匯入最大心率
            "max heart":int(scopemaxB),
            #匯入最小心率
            "min heart":int(scopeminB),
            #匯入心率變化範圍
            "max to min scope heart":int(scopeB),
            #匯入資訊熵
            "entropy of information":float(HB),
            #匯入均方根
            "root mean square":float(meanrB),
            #匯入標準化均值
            "standardize average":float(aveb),
        }
        )
        return datas

    def create_data(es, datas):
        for data in datas:
            es.index(index='ling-林郁芮01text', body=data)

    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        datas = load_datas()
        create_data(es, datas)
    print("C視頻心率特徵: ")

    #平均
    aveD = 0.0
    for i in range(0,D):
        aveD +=arrd[i]
    aveD = aveD/D
    print("平均: ",aveD)

    #DiffD1 一階差的平均值
    diffD1 = 0.0
    meanD1 = 0.0
    #X[n+1]-X[n]的總和
    for i in range(0,(D-1)):
        meanD1 += abs(arrd[i+1]-arrd[i])
    diffD1 = meanD1/(D-1)
    print("一階差: ",diffD1)

    #DiffD2 二階差的平均值
    diffD2 = 0.0
    meanD2 = 0.0
    #X[n+2]-X[n]的總和
    for i in range(0,(D-2)):
        meanD2 += abs(arrd[i+2]-arrd[i])
    diffD2 = meanD2/(D-2)
    print("二階差: ",diffD2)

    #range 心率變化範圍
    scopeD = 0
    scopemaxD = 0
    scopeminD = 110
    for i in range(0,D):
        #求最大心率
        if arrd[i]>scopemaxD:
            scopemaxD = arrd[i]
        #求最小心率
        if arrd[i]<scopeminD:
            scopeminD = arrd[i]
    scopeD = scopemaxD-scopeminD
    print("最大心率: ",scopemaxD)
    print("最小心率: ",scopeminD)
    print("心率變化範圍: ",scopeD)

    #H(X)資訊熵
    x = 0
    HD = 0
    arrpd = [0.0]*D
    for i in range(0,D):
        x = 0 #初值為0 
        #心率出現次數
        for j in range(0,D):
            if arrd[i]==arrd[j]:
                x+=1
        arrpd[i] = x*1.0/D
    for k in range(0,D):
        HD += -arrpd[k]*math.log(arrpd[k],2)
    print("資訊熵: ",HD)

    #Radrm 均方根
    radrmD = 0.0
    meanrD = 0.0
    #相鄰值平方差的總和
    for i in range(0,(D-1)):
        radrmD += pow(arrd[i+1]-arrd[i],2)
    meanrD = radrmD/D
    print("均方根: ",meanrD)

    #標準化均值
    arrdd = [0.0]*D
    aved = 0.0
    for i in range(0,D):
        arrdd[i] = arrd[i] -ave
        aved +=arrdd[i]
    aved = aved/D
    print("標準化均值: ",aved)
    
    #匯入資料
    def load_datas():
        datas = list()
        datas.append(
        {
            #匯入編號
            "Number": int(n),
            #匯入名字
            "name": name,
            #匯入影片類別
            "video type": "C",
            #匯入平均
            "average": float(aveD),
            #匯入一階差
            "first order difference":float(diffD1),
            #匯入二階差
            "second order difference":float(diffD2),
            #匯入最大心率
            "max heart":int(scopemaxD),
            #匯入最小心率
            "min heart":int(scopeminD),
            #匯入心率變化範圍
            "max to min scope heart":int(scopeD),
            #匯入資訊熵
            "entropy of information":float(HD),
            #匯入均方根
            "root mean square":float(meanrD),
            #匯入標準化均值
            "standardize average":float(aved),
        }
        )
        return datas

    def create_data(es, datas):
        for data in datas:
            es.index(index='ling-林郁芮01text', body=data)

    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        datas = load_datas()
        create_data(es, datas)
# Out:
# A
# 99
# A
# 95
# A
# 102
# A
# 96
# A
# 91
# [99, 95, 102, 96, 91]
# B
# 97
# B
# 93
# B
# 94
# B
# 95
# B
# 95
# [97, 93, 94, 95, 95]
# C
# 94
# C
# 92
# C
# 90
# C
# 89
# C
# 86
# [94, 92, 90, 89, 86]
# A視頻心率特徵 :
# 平均:  94.8
# 一階差:  1.5
# 二階差:  2.0
# 最大心率:  97
# 最小心率:  93
# 心率變化範圍:  4
# 資訊熵:  2.4506993328423072
# 均方根:  3.6
# 標準化均值:  -1.7999999999999943
# C視頻心率特徵:
# 平均:  90.2
# 一階差:  2.0
# 二階差:  3.6666666666666665
# 最大心率:  94
# 最小心率:  86
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  3.6
# 標準化均值:  -6.399999999999994
# A
# 92
# A
# 97
# A
# 100
# A
# 94
# A
# 90
# [92, 97, 100, 94, 90]
# B
# 96
# B
# 94
# B
# 93
# B
# 96
# B
# 96
# [96, 94, 93, 96, 96]
# C
# 93
# C
# 93
# C
# 88
# C
# 88
# C
# 87
# [93, 93, 88, 88, 87]
# A視頻心率特徵 :
# 平均:  95.0
# 一階差:  1.5
# 二階差:  2.6666666666666665
# 最大心率:  96
# 最小心率:  93
# 心率變化範圍:  3
# 資訊熵:  2.2553093074541164
# 均方根:  2.8
# 標準化均值:  0.4000000000000057
# C視頻心率特徵:
# 平均:  89.8
# 一階差:  1.5
# 二階差:  3.6666666666666665
# 最大心率:  93
# 最小心率:  87
# 心率變化範圍:  6
# 資訊熵:  2.579470570797252
# 均方根:  5.2
# 標準化均值:  -4.7999999999999945
# A
# 91
# A
# 98
# A
# 99
# A
# 93
# A
# 92
# [91, 98, 99, 93, 92]
# B
# 97
# B
# 95
# B
# 94
# B
# 97
# B
# 95
# [97, 95, 94, 97, 95]
# C
# 92
# C
# 91
# C
# 89
# C
# 87
# C
# 88
# [92, 91, 89, 87, 88]
# A視頻心率特徵 :
# 平均:  95.6
# 一階差:  2.0
# 二階差:  2.0
# 最大心率:  97
# 最小心率:  94
# 心率變化範圍:  3
# 資訊熵:  2.579470570797252
# 均方根:  3.6
# 標準化均值:  1.0000000000000058
# C視頻心率特徵:
# 平均:  89.4
# 一階差:  1.5
# 二階差:  2.6666666666666665
# 最大心率:  92
# 最小心率:  87
# 心率變化範圍:  5
# 資訊熵:  2.321928094887362
# 均方根:  2.0
# 標準化均值:  -5.199999999999994
# A
# 90
# A
# 97
# A
# 98
# A
# 92
# A
# 93
# [90, 97, 98, 92, 93]
# B
# 98
# B
# 93
# B
# 95
# B
# 96
# B
# 95
# [98, 93, 95, 96, 95]
# C
# 91
# C
# 90
# C
# 90
# C
# 88
# C
# 85
# [91, 90, 90, 88, 85]
# A視頻心率特徵 :
# 平均:  95.4
# 一階差:  2.25
# 二階差:  2.0
# 最大心率:  98
# 最小心率:  93
# 心率變化範圍:  5
# 資訊熵:  2.4506993328423072
# 均方根:  6.2
# 標準化均值:  1.4
# C視頻心率特徵:
# 平均:  88.8
# 一階差:  1.5
# 二階差:  2.6666666666666665
# 最大心率:  91
# 最小心率:  85
# 心率變化範圍:  6
# 資訊熵:  2.450699332842307
# 均方根:  2.8
# 標準化均值:  -5.2
# A
# 92
# A
# 103
# A
# 95
# A
# 100
# A
# 95
# [92, 103, 95, 100, 95]
# B
# 94
# B
# 92
# B
# 92
# B
# 98
# B
# 94
# [94, 92, 92, 98, 94]
# C
# 92
# C
# 91
# C
# 91
# C
# 89
# C
# 87
# [92, 91, 91, 89, 87]
# A視頻心率特徵 :
# 平均:  94.0
# 一階差:  3.0
# 二階差:  3.3333333333333335
# 最大心率:  98
# 最小心率:  92
# 心率變化範圍:  6
# 資訊熵:  2.579470570797252
# 均方根:  11.2
# 標準化均值:  -3.0
# C視頻心率特徵:
# 平均:  90.0
# 一階差:  1.25
# 二階差:  2.3333333333333335
# 最大心率:  92
# 最小心率:  87
# 心率變化範圍:  5
# 資訊熵:  2.450699332842307
# 均方根:  1.8
# 標準化均值:  -7.0
# A
# 91
# A
# 104
# A
# 93
# A
# 99
# A
# 96
# [91, 104, 93, 99, 96]
# B
# 93
# B
# 91
# B
# 91
# B
# 97
# B
# 93
# [93, 91, 91, 97, 93]
# C
# 91
# C
# 92
# C
# 94
# C
# 87
# C
# 88
# [91, 92, 94, 87, 88]
# A視頻心率特徵 :
# 平均:  93.0
# 一階差:  3.0
# 二階差:  3.3333333333333335
# 最大心率:  97
# 最小心率:  91
# 心率變化範圍:  6
# 資訊熵:  2.579470570797252
# 均方根:  11.2
# 標準化均值:  -3.5999999999999943
# C視頻心率特徵:
# 平均:  90.4
# 一階差:  2.75
# 二階差:  4.666666666666667
# 最大心率:  94
# 最小心率:  87
# 心率變化範圍:  7
# 資訊熵:  2.321928094887362
# 均方根:  11.0
# 標準化均值:  -6.199999999999994
# A
# 93
# A
# 105
# A
# 92
# A
# 98
# A
# 97
# [93, 105, 92, 98, 97]
# B
# 92
# B
# 90
# B
# 90
# B
# 98
# B
# 92
# [92, 90, 90, 98, 92]
# C
# 92
# C
# 93
# C
# 93
# C
# 86
# C
# 86
# [92, 93, 93, 86, 86]
# A視頻心率特徵 :
# 平均:  92.4
# 一階差:  4.0
# 二階差:  4.0
# 最大心率:  98
# 最小心率:  90
# 心率變化範圍:  8
# 資訊熵:  2.579470570797252
# 均方根:  20.8
# 標準化均值:  -4.6
# C視頻心率特徵:
# 平均:  90.0
# 一階差:  2.0
# 二階差:  5.0
# 最大心率:  93
# 最小心率:  86
# 心率變化範圍:  7
# 資訊熵:  2.579470570797252
# 均方根:  10.0
# 標準化均值:  -7.0
# A
# 94
# A
# 104
# A
# 94
# A
# 93
# A
# 98
# [94, 104, 94, 93, 98]
# B
# 91
# B
# 91
# B
# 92
# B
# 99
# B
# 93
# [91, 91, 92, 99, 93]
# C
# 91
# C
# 94
# C
# 90
# C
# 87
# C
# 85
# [91, 94, 90, 87, 85]
# A視頻心率特徵 :
# 平均:  93.2
# 一階差:  3.5
# 二階差:  3.3333333333333335
# 最大心率:  99
# 最小心率:  91
# 心率變化範圍:  8
# 資訊熵:  2.450699332842307
# 均方根:  17.2
# 標準化均值:  -3.399999999999994
# C視頻心率特徵:
# 平均:  89.4
# 一階差:  3.0
# 二階差:  4.333333333333333
# 最大心率:  94
# 最小心率:  85
# 心率變化範圍:  9
# 資訊熵:  2.321928094887362
# 均方根:  7.6
# 標準化均值:  -7.199999999999994
# A
# 95
# A
# 105
# A
# 93
# A
# 92
# A
# 96
# [95, 105, 93, 92, 96]
# B
# 90
# B
# 92
# B
# 91
# B
# 98
# B
# 94
# [90, 92, 91, 98, 94]
# C
# 90
# C
# 92
# C
# 89
# C
# 88
# C
# 86
# [90, 92, 89, 88, 86]
# A視頻心率特徵 :
# 平均:  93.0
# 一階差:  3.5
# 二階差:  3.3333333333333335
# 最大心率:  98
# 最小心率:  90
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  14.0
# 標準化均值:  -3.200000000000003
# C視頻心率特徵:
# 平均:  89.0
# 一階差:  2.0
# 二階差:  2.6666666666666665
# 最大心率:  92
# 最小心率:  86
# 心率變化範圍:  6
# 資訊熵:  2.321928094887362
# 均方根:  3.6
# 標準化均值:  -7.200000000000003
# A
# 96
# A
# 103
# A
# 95
# A
# 90
# A
# 102
# [96, 103, 95, 90, 102]
# B
# 92
# B
# 93
# B
# 94
# B
# 96
# B
# 93
# [92, 93, 94, 96, 93]
# C
# 91
# C
# 91
# C
# 90
# C
# 87
# C
# 87
# [91, 91, 90, 87, 87]
# A視頻心率特徵 :
# 平均:  93.6
# 一階差:  1.75
# 二階差:  2.0
# 最大心率:  96
# 最小心率:  92
# 心率變化範圍:  4
# 資訊熵:  2.4506993328423072
# 均方根:  3.0
# 標準化均值:  -3.6000000000000028
# C視頻心率特徵:
# 平均:  89.2
# 一階差:  1.0
# 二階差:  2.6666666666666665
# 最大心率:  91
# 最小心率:  87
# 心率變化範圍:  4
# 資訊熵:  2.579470570797252
# 均方根:  2.0
# 標準化均值:  -8.000000000000004
# A
# 95
# A
# 102
# A
# 96
# A
# 91
# A
# 103
# [95, 102, 96, 91, 103]
# B
# 93
# B
# 94
# B
# 95
# B
# 95
# B
# 91
# [93, 94, 95, 95, 91]
# C
# 92
# C
# 90
# C
# 89
# C
# 86
# C
# 86
# [92, 90, 89, 86, 86]
# A視頻心率特徵 :
# 平均:  93.6
# 一階差:  1.5
# 二階差:  2.3333333333333335
# 最大心率:  95
# 最小心率:  91
# 心率變化範圍:  4
# 資訊熵:  2.4506993328423072
# 均方根:  3.6
# 標準化均值:  -3.8000000000000056
# C視頻心率特徵:
# 平均:  88.6
# 一階差:  1.5
# 二階差:  3.3333333333333335
# 最大心率:  92
# 最小心率:  86
# 心率變化範圍:  6
# 資訊熵:  2.4506993328423072
# 均方根:  2.8
# 標準化均值:  -8.800000000000006
# A
# 97
# A
# 100
# A
# 94
# A
# 90
# A
# 100
# [97, 100, 94, 90, 100]
# B
# 94
# B
# 93
# B
# 96
# B
# 96
# B
# 90
# [94, 93, 96, 96, 90]
# C
# 93
# C
# 88
# C
# 88
# C
# 87
# C
# 87
# [93, 88, 88, 87, 87]
# A視頻心率特徵 :
# 平均:  93.8
# 一階差:  2.5
# 二階差:  3.6666666666666665
# 最大心率:  96
# 最小心率:  90
# 心率變化範圍:  6
# 資訊熵:  2.4506993328423072
# 均方根:  9.2
# 標準化均值:  -2.400000000000003
# C視頻心率特徵:
# 平均:  88.6
# 一階差:  1.5
# 二階差:  2.3333333333333335
# 最大心率:  93
# 最小心率:  87
# 心率變化範圍:  6
# 資訊熵:  2.579470570797252
# 均方根:  5.2
# 標準化均值:  -7.600000000000003
# A
# 98
# A
# 99
# A
# 93
# A
# 92
# A
# 101
# [98, 99, 93, 92, 101]
# B
# 95
# B
# 94
# B
# 97
# B
# 95
# B
# 92
# [95, 94, 97, 95, 92]
# C
# 91
# C
# 89
# C
# 87
# C
# 88
# C
# 86
# [91, 89, 87, 88, 86]
# A視頻心率特徵 :
# 平均:  94.6
# 一階差:  2.25
# 二階差:  2.6666666666666665
# 最大心率:  97
# 最小心率:  92
# 心率變化範圍:  5
# 資訊熵:  2.4506993328423072
# 均方根:  4.6
# 標準化均值:  -1.9999999999999942
# C視頻心率特徵:
# 平均:  88.2
# 一階差:  1.75
# 二階差:  2.0
# 最大心率:  91
# 最小心率:  86
# 心率變化範圍:  5
# 資訊熵:  2.321928094887362
# 均方根:  2.6
# 標準化均值:  -8.399999999999995
# A
# 97
# A
# 98
# A
# 92
# A
# 93
# A
# 98
# [97, 98, 92, 93, 98]
# B
# 93
# B
# 95
# B
# 96
# B
# 95
# B
# 89
# [93, 95, 96, 95, 89]
# C
# 90
# C
# 90
# C
# 88
# C
# 85
# C
# 84
# [90, 90, 88, 85, 84]
# A視頻心率特徵 :
# 平均:  93.6
# 一階差:  2.5
# 二階差:  3.3333333333333335
# 最大心率:  96
# 最小心率:  89
# 心率變化範圍:  7
# 資訊熵:  2.4506993328423072
# 均方根:  8.4
# 標準化均值:  -1.9999999999999942
# C視頻心率特徵:
# 平均:  87.4
# 一階差:  1.5
# 二階差:  3.6666666666666665
# 最大心率:  90
# 最小心率:  84
# 心率變化範圍:  6
# 資訊熵:  2.450699332842307
# 均方根:  2.8
# 標準化均值:  -8.199999999999994
# A
# 103
# A
# 95
# A
# 100
# A
# 95
# A
# 97
# [103, 95, 100, 95, 97]
# B
# 92
# B
# 92
# B
# 98
# B
# 94
# B
# 91
# [92, 92, 98, 94, 91]
# C
# 91
# C
# 91
# C
# 89
# C
# 87
# C
# 85
# [91, 91, 89, 87, 85]
# A視頻心率特徵 :
# 平均:  93.4
# 一階差:  3.25
# 二階差:  5.0
# 最大心率:  98
# 最小心率:  91
# 心率變化範圍:  7
# 資訊熵:  2.450699332842307
# 均方根:  12.2
# 標準化均值:  -4.6
# C視頻心率特徵:
# 平均:  88.6
# 一階差:  1.5
# 二階差:  3.3333333333333335
# 最大心率:  91
# 最小心率:  85
# 心率變化範圍:  6
# 資訊熵:  2.450699332842307
# 均方根:  2.4
# 標準化均值:  -9.4
# A
# 104
# A
# 93
# A
# 99
# A
# 96
# A
# 96
# [104, 93, 99, 96, 96]
# B
# 91
# B
# 91
# B
# 97
# B
# 93
# B
# 92
# [91, 91, 97, 93, 92]
# C
# 92
# C
# 94
# C
# 87
# C
# 88
# C
# 86
# [92, 94, 87, 88, 86]
# A視頻心率特徵 :
# 平均:  92.8
# 一階差:  2.75
# 二階差:  4.333333333333333
# 最大心率:  97
# 最小心率:  91
# 心率變化範圍:  6
# 資訊熵:  2.450699332842307
# 均方根:  10.6
# 標準化均值:  -4.7999999999999945
# C視頻心率特徵:
# 平均:  89.4
# 一階差:  3.0
# 二階差:  4.0
# 最大心率:  94
# 最小心率:  86
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  11.6
# 標準化均值:  -8.199999999999994
# A
# 105
# A
# 92
# A
# 98
# A
# 97
# A
# 97
# [105, 92, 98, 97, 97]
# B
# 90
# B
# 90
# B
# 98
# B
# 92
# B
# 93
# [90, 90, 98, 92, 93]
# C
# 93
# C
# 93
# C
# 86
# C
# 86
# C
# 85
# [93, 93, 86, 86, 85]
# A視頻心率特徵 :
# 平均:  92.6
# 一階差:  3.75
# 二階差:  5.0
# 最大心率:  98
# 最小心率:  90
# 心率變化範圍:  8
# 資訊熵:  2.450699332842307
# 均方根:  20.2
# 標準化均值:  -5.1999999999999975
# C視頻心率特徵:
# 平均:  88.6
# 一階差:  2.0
# 二階差:  5.0
# 最大心率:  93
# 最小心率:  85
# 心率變化範圍:  8
# 資訊熵:  2.579470570797252
# 均方根:  10.0
# 標準化均值:  -9.199999999999998
# A
# 104
# A
# 94
# A
# 93
# A
# 98
# A
# 96
# [104, 94, 93, 98, 96]
# B
# 91
# B
# 92
# B
# 99
# B
# 93
# B
# 94
# [91, 92, 99, 93, 94]
# C
# 94
# C
# 90
# C
# 87
# C
# 85
# C
# 86
# [94, 90, 87, 85, 86]
# A視頻心率特徵 :
# 平均:  93.8
# 一階差:  3.75
# 二階差:  4.666666666666667
# 最大心率:  99
# 最小心率:  91
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  17.4
# 標準化均值:  -3.2
# C視頻心率特徵:
# 平均:  88.4
# 一階差:  2.5
# 二階差:  4.333333333333333
# 最大心率:  94
# 最小心率:  85
# 心率變化範圍:  9
# 資訊熵:  2.321928094887362
# 均方根:  6.0
# 標準化均值:  -8.6
# A
# 105
# A
# 93
# A
# 92
# A
# 96
# A
# 95
# [105, 93, 92, 96, 95]
# B
# 92
# B
# 91
# B
# 98
# B
# 94
# B
# 92
# [92, 91, 98, 94, 92]
# C
# 92
# C
# 89
# C
# 88
# C
# 86
# C
# 84
# [92, 89, 88, 86, 84]
# A視頻心率特徵 :
# 平均:  93.4
# 一階差:  3.5
# 二階差:  5.0
# 最大心率:  98
# 最小心率:  91
# 心率變化範圍:  7
# 資訊熵:  2.4506993328423072
# 均方根:  14.0
# 標準化均值:  -2.800000000000003
# C視頻心率特徵:
# 平均:  87.8
# 一階差:  2.0
# 二階差:  3.6666666666666665
# 最大心率:  92
# 最小心率:  84
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  3.6
# 標準化均值:  -8.400000000000002
# A
# 103
# A
# 95
# A
# 90
# A
# 102
# A
# 96
# [103, 95, 90, 102, 96]
# B
# 93
# B
# 94
# B
# 96
# B
# 93
# B
# 93
# [93, 94, 96, 93, 93]
# C
# 91
# C
# 90
# C
# 87
# C
# 87
# C
# 83
# [91, 90, 87, 87, 83]
# A視頻心率特徵 :
# 平均:  93.8
# 一階差:  1.5
# 二階差:  2.3333333333333335
# 最大心率:  96
# 最小心率:  93
# 心率變化範圍:  3
# 資訊熵:  2.2553093074541164
# 均方根:  2.8
# 標準化均值:  -3.400000000000003
# C視頻心率特徵:
# 平均:  87.6
# 一階差:  2.0
# 二階差:  3.6666666666666665
# 最大心率:  91
# 最小心率:  83
# 心率變化範圍:  8
# 資訊熵:  2.4506993328423072
# 均方根:  5.2
# 標準化均值:  -9.600000000000003
# A
# 102
# A
# 96
# A
# 91
# A
# 103
# A
# 95
# [102, 96, 91, 103, 95]
# B
# 94
# B
# 95
# B
# 95
# B
# 91
# B
# 94
# [94, 95, 95, 91, 94]
# C
# 90
# C
# 89
# C
# 86
# C
# 86
# C
# 83
# [90, 89, 86, 86, 83]
# A視頻心率特徵 :
# 平均:  93.8
# 一階差:  2.0
# 二階差:  2.0
# 最大心率:  95
# 最小心率:  91
# 心率變化範圍:  4
# 資訊熵:  2.579470570797252
# 均方根:  5.2
# 標準化均值:  -3.600000000000006
# C視頻心率特徵:
# 平均:  86.8
# 一階差:  1.75
# 二階差:  3.3333333333333335
# 最大心率:  90
# 最小心率:  83
# 心率變化範圍:  7
# 資訊熵:  2.4506993328423072
# 均方根:  3.8
# 標準化均值:  -10.600000000000005
# A
# 100
# A
# 94
# A
# 90
# A
# 100
# A
# 96
# [100, 94, 90, 100, 96]
# B
# 93
# B
# 96
# B
# 96
# B
# 90
# B
# 95
# [93, 96, 96, 90, 95]
# C
# 88
# C
# 88
# C
# 87
# C
# 87
# C
# 82
# [88, 88, 87, 87, 82]
# A視頻心率特徵 :
# 平均:  94.0
# 一階差:  3.5
# 二階差:  3.3333333333333335
# 最大心率:  96
# 最小心率:  90
# 心率變化範圍:  6
# 資訊熵:  2.450699332842307
# 均方根:  14.0
# 標準化均值:  -2.0
# C視頻心率特徵:
# 平均:  86.4
# 一階差:  1.5
# 二階差:  2.3333333333333335
# 最大心率:  88
# 最小心率:  82
# 心率變化範圍:  6
# 資訊熵:  2.579470570797252
# 均方根:  5.2
# 標準化均值:  -9.6
# A
# 99
# A
# 93
# A
# 92
# A
# 101
# A
# 95
# [99, 93, 92, 101, 95]
# B
# 94
# B
# 97
# B
# 95
# B
# 92
# B
# 94
# [94, 97, 95, 92, 94]
# C
# 89
# C
# 87
# C
# 88
# C
# 86
# C
# 84
# [89, 87, 88, 86, 84]
# A視頻心率特徵 :
# 平均:  94.4
# 一階差:  2.5
# 二階差:  2.3333333333333335
# 最大心率:  97
# 最小心率:  92
# 心率變化範圍:  5
# 資訊熵:  2.4506993328423072
# 均方根:  5.2
# 標準化均值:  -1.6
# C視頻心率特徵:
# 平均:  86.8
# 一階差:  1.75
# 二階差:  2.0
# 最大心率:  89
# 最小心率:  84
# 心率變化範圍:  5
# 資訊熵:  2.321928094887362
# 均方根:  2.6
# 標準化均值:  -9.2
# A
# 98
# A
# 92
# A
# 93
# A
# 98
# A
# 99
# [98, 92, 93, 98, 99]
# B
# 95
# B
# 96
# B
# 95
# B
# 89
# B
# 92
# [95, 96, 95, 89, 92]
# C
# 90
# C
# 88
# C
# 85
# C
# 84
# C
# 85
# [90, 88, 85, 84, 85]
# A視頻心率特徵 :
# 平均:  93.4
# 一階差:  2.75
# 二階差:  3.3333333333333335
# 最大心率:  96
# 最小心率:  89
# 心率變化範圍:  7
# 資訊熵:  2.450699332842307
# 均方根:  9.4
# 標準化均值:  -2.6
# C視頻心率特徵:
# 平均:  86.4
# 一階差:  1.75
# 二階差:  3.0
# 最大心率:  90
# 最小心率:  84
# 心率變化範圍:  6
# 資訊熵:  2.4506993328423072
# 均方根:  3.0
# 標準化均值:  -9.6
# A
# 95
# A
# 100
# A
# 95
# A
# 97
# A
# 98
# [95, 100, 95, 97, 98]
# B
# 92
# B
# 98
# B
# 94
# B
# 91
# B
# 91
# [92, 98, 94, 91, 91]
# C
# 91
# C
# 89
# C
# 87
# C
# 85
# C
# 87
# [91, 89, 87, 85, 87]
# A視頻心率特徵 :
# 平均:  93.2
# 一階差:  3.25
# 二階差:  4.0
# 最大心率:  98
# 最小心率:  91
# 心率變化範圍:  7
# 資訊熵:  2.4506993328423072
# 均方根:  12.2
# 標準化均值:  -3.8
# C視頻心率特徵:
# 平均:  87.8
# 一階差:  2.0
# 二階差:  2.6666666666666665
# 最大心率:  91
# 最小心率:  85
# 心率變化範圍:  6
# 資訊熵:  2.4506993328423072
# 均方根:  3.2
# 標準化均值:  -9.2
