# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts='140.137.41.81', port=9200)

# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import metrics
import operator
import math

# %%
#建立ling-張哲唯01text資料庫

from elasticsearch import Elasticsearch
import json

def create_index(es):
    body = dict()
    body['settings'] = get_setting()
    body['mappings'] = get_mappings()
    print(json.dumps(body)) #可以用json.dumps輸出來看格式有沒又包錯
    es.indices.create(index='ling-張哲唯01text', body=body)

def get_setting():
    settings = {
        "index": {
            "number_of_shards": 3,
            "number_of_replicas": 2
        }
    }
    return settings

def get_mappings():
    mappings = {
        "properties": {
            #編號
            "Number": {
                "type": "integer"
            },
            #編號
            "name": {
                "type": "keyword"
            },
            #影片類別
            "video type": {
                "type": "keyword"
            },
            #平均
            "average": {
                "type": "float"
            },
            #一階差
            "first order difference": {
                "type": "float"
            },
            #二階差
            "second order difference": {
                "type": "float"
            },
            #最大心率
            "max heart": {
                "type": "integer"
            },
            #最小心率
            "min heart": {
                "type": "integer"
            },
            #心率變化範圍
            "max to min scope heart": {
                "type": "integer"
            },
            #資訊熵
            "entropy of information": {
                "type": "float"
            },
            #均方根
            "root mean square": {
                "type": "float"
            },
            #標準化均值
            "standardize average": {
                "type": "float"
            }
        }
    }
    return mappings

if __name__ == "__main__":
    es = Elasticsearch(hosts='140.137.41.81', port=9200)
    create_index(es)
# Out:
# {"settings": {"index": {"number_of_shards": 3, "number_of_replicas": 2}}, "mappings": {"properties": {"Number": {"type": "integer"}, "name": {"type": "keyword"}, "video type": {"type": "keyword"}, "average": {"type": "float"}, "first order difference": {"type": "float"}, "second order difference": {"type": "float"}, "max heart": {"type": "integer"}, "min heart": {"type": "integer"}, "max to min scope heart": {"type": "integer"}, "entropy of information": {"type": "float"}, "root mean square": {"type": "float"}, "standardize average": {"type": "float"}}}}

# %%
#將ling-張哲唯數據01的1st進行計算並且將結果傳送到ling-張哲唯01text資料庫

from elasticsearch import Elasticsearch
import json

# 正常(feel=naturl)心率取5個為一組
SamplesStartA = 0
SamplesStopA = 50

#A視頻(feel=happy)心率取5個為一組
SamplesStartB = 0
SamplesStopB = 50

#C視頻(feel=sad)心率取5個為一組
SamplesStartC = 0
SamplesStopC = 50

name="張哲唯"

arra=[0]*5
x=0
arrb=[0]*5
y=0
arrd=[0]*5
z=0

A=5
B=5
D=5

for n in range(0,25): #迴圈取[a1,a11,a21,...],[a2,a22,a33...],[a3,a23,a33...]...共取25組
    arra=[0]*5
    x=0
    arrb=[0]*5
    y=0
    arrd=[0]*5
    z=0
    A=5
    B=5
    D=5
    SamplesStartA+=1
    SamplesStopA+=1
    SamplesStartB+=1
    SamplesStopB+=1
    SamplesStartC+=1
    SamplesStopC+=1
    for m in range(SamplesStartA,SamplesStopA,10):  #迴圈取a1,a11,a21,a31,a41...一組取5個
        def get_queryA():
            queryA = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "name": "張哲唯"
                        }
                    },
                        {
                        "term": {
                            "feel": "natural"
                        }
                    },
                    {
                        "term": {
                            "time": m
                        }
                    },
                        {
                        "term": {
                            "trial": "1st"
                        }
                    }]
                }
            }
        }
            return queryA
        if __name__ == "__main__":
            es = Elasticsearch(hosts='140.137.41.81', port=9200)
            queryA = get_queryA()
            resultA = es.search(index='ling-張哲唯數據01', body=queryA)
            resultaa=json.dumps(resultA, ensure_ascii=False)
            resultPulseA=json.loads(resultaa)
            print("A")
            print(resultPulseA['hits']['hits'][0]['_source']['pulse'])
            aa=resultPulseA['hits']['hits'][0]['_source']['pulse']
            arra[x]=aa
            if x==4:
                print(arra)
                x-=4
            else:
                x+=1
    for p in range(SamplesStartB,SamplesStopB,10):  #迴圈取A視頻心率a1,a11,a21,a31,a41...一組取5個
        def get_queryB():
            queryB = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "name": "張哲唯"
                        }
                    },
                        {
                        "term": {
                            "feel": "happy"
                        }
                    },
                    {
                        "term": {
                            "time": p
                        }
                    },
                        {
                        "term": {
                            "trial": "1st"
                        }
                    }]
                }
            }
        }
            return queryB
        if __name__ == "__main__":
            es = Elasticsearch(hosts='140.137.41.81', port=9200)
            queryB = get_queryB()
            resultB = es.search(index='ling-張哲唯數據01', body=queryB)
            resultbb=json.dumps(resultB, ensure_ascii=False)
            resultPulseB=json.loads(resultbb)
            print("B")
            print(resultPulseB['hits']['hits'][0]['_source']['pulse'])
            bb=resultPulseB['hits']['hits'][0]['_source']['pulse']
            arrb[y]=bb
            if y==4:
                print(arrb)
                y-=4
            else:
                y+=1
    for q in range(SamplesStartC,SamplesStopC,10):     #迴圈取C視頻心率a1,a11,a21,a31,a41...一組取5個
        def get_queryC():
            queryC = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "name": "張哲唯"
                        }
                    },
                        {
                        "term": {
                            "feel": "sad"
                        }
                    },
                    {
                        "term": {
                            "time": q
                        }
                    },
                        {
                        "term": {
                            "trial": "1st"
                        }
                    }]
                }
            }
        }
            return queryC
        if __name__ == "__main__":
            es = Elasticsearch(hosts='140.137.41.81', port=9200)
            queryC = get_queryC()
            resultC = es.search(index='ling-張哲唯數據01', body=queryC)
            resultcc=json.dumps(resultC, ensure_ascii=False)
            resultPulseC=json.loads(resultcc)
            print("C")
            print(resultPulseC['hits']['hits'][0]['_source']['pulse'])
            cc=resultPulseC['hits']['hits'][0]['_source']['pulse']
            arrd[z]=cc
            if z==4:
                print(arrd)
                z-=4
            else:
                z+=1
    #正常心率平均
    ave = 0.0
    for i in range(0,A):
        ave+=arra[i]
    ave = ave/A

    print("A視頻心率特徵 :")

    #平均
    aveB = 0.0
    for i in range(0,B):
        aveB +=arrb[i]
    aveB = aveB/B
    print("平均: ",aveB)

    #DiffB1 一階差的平均值
    diffB1 = 0.0
    meanB1 = 0.0
    #X[n-1]-X[n]的總和
    for i in range(0,(B-1)):
        meanB1+=abs(arrb[i+1]-arrb[i])
    diffB1 = meanB1/(B-1)
    print("一階差: ",diffB1)

    #DiffB2 二階差的平均值
    diffB2 = 0.0
    meanB2 = 0.0
    #X[n+2]-X[n]的總和
    for i in range(0,(B-2)):
        meanB2 += abs(arrb[i+2]-arrb[i])
    diffB2 = meanB2/(B-2)
    print("二階差: ",diffB2)

    #range 心率變化範圍
    scopeB = 0
    scopemaxB = 0
    scopeminB = 110
    for i in range(0,B):
        #求最大心率
        if arrb[i]>scopemaxB:
            scopemaxB = arrb[i]
        if arrb[i]<scopeminB:
            scopeminB = arrb[i]
    scopeB = scopemaxB-scopeminB
    print("最大心率: ",scopemaxB)
    print("最小心率: ",scopeminB)
    print("心率變化範圍: ",scopeB)

    #H(X)資訊熵
    x = 0
    HB = 0
    arrpb = [0.0]*B
    for i in range(0,B):
        x=0 #初值為0
        #心率出現次數
        for j in range(0,B):
            if arrb[i]==arrb[j]:
                x+=1
        #p[i]機率
        arrpb[i] = x*1.0/B
    for k in range(0,B):
        HB += -arrpb[k]*math.log(arrpb[k],2)
    print("資訊熵: ",HB)

    #Radrm 均方根
    radrmB = 0.0   
    meanrB = 0.0
    #相鄰值平方差的總和
    for i in range(0,(B-1)):
        radrmB += pow(arrb[i+1]-arrb[i],2)
    meanrB = radrmB/B
    print("均方根: ",meanrB)

    #標準化均值
    arrbb=[0.0]*B
    aveb = 0.0
    for i in range(0,B):
        arrbb[i] = arrb[i]-ave
        aveb += arrbb[i]
    aveb = aveb/B
    print("標準化均值: ",aveb)
    def load_datas():
        datas = list()
        datas.append(
        {
            #匯入編號
            "Number": int(n),
            #匯入名字
            "name": name,
            #匯入影片類別
            "video type": "A",
            #匯入平均
            "average": float(aveB),
            #匯入一階差
            "first order difference":float(diffB1),
            #匯入二階差
            "second order difference":float(diffB2),
            #匯入最大心率
            "max heart":int(scopemaxB),
            #匯入最小心率
            "min heart":int(scopeminB),
            #匯入心率變化範圍
            "max to min scope heart":int(scopeB),
            #匯入資訊熵
            "entropy of information":float(HB),
            #匯入均方根
            "root mean square":float(meanrB),
            #匯入標準化均值
            "standardize average":float(aveb),
        }
        )
        return datas

    def create_data(es, datas):
        for data in datas:
            es.index(index='ling-張哲唯01text', body=data)

    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        datas = load_datas()
        create_data(es, datas)
    print("C視頻心率特徵: ")

    #平均
    aveD = 0.0
    for i in range(0,D):
        aveD +=arrd[i]
    aveD = aveD/D
    print("平均: ",aveD)

    #DiffD1 一階差的平均值
    diffD1 = 0.0
    meanD1 = 0.0
    #X[n+1]-X[n]的總和
    for i in range(0,(D-1)):
        meanD1 += abs(arrd[i+1]-arrd[i])
    diffD1 = meanD1/(D-1)
    print("一階差: ",diffD1)

    #DiffD2 二階差的平均值
    diffD2 = 0.0
    meanD2 = 0.0
    #X[n+2]-X[n]的總和
    for i in range(0,(D-2)):
        meanD2 += abs(arrd[i+2]-arrd[i])
    diffD2 = meanD2/(D-2)
    print("二階差: ",diffD2)

    #range 心率變化範圍
    scopeD = 0
    scopemaxD = 0
    scopeminD = 110
    for i in range(0,D):
        #求最大心率
        if arrd[i]>scopemaxD:
            scopemaxD = arrd[i]
        #求最小心率
        if arrd[i]<scopeminD:
            scopeminD = arrd[i]
    scopeD = scopemaxD-scopeminD
    print("最大心率: ",scopemaxD)
    print("最小心率: ",scopeminD)
    print("心率變化範圍: ",scopeD)

    #H(X)資訊熵
    x = 0
    HD = 0
    arrpd = [0.0]*D
    for i in range(0,D):
        x = 0 #初值為0 
        #心率出現次數
        for j in range(0,D):
            if arrd[i]==arrd[j]:
                x+=1
        arrpd[i] = x*1.0/D
    for k in range(0,D):
        HD += -arrpd[k]*math.log(arrpd[k],2)
    print("資訊熵: ",HD)

    #Radrm 均方根
    radrmD = 0.0
    meanrD = 0.0
    #相鄰值平方差的總和
    for i in range(0,(D-1)):
        radrmD += pow(arrd[i+1]-arrd[i],2)
    meanrD = radrmD/D
    print("均方根: ",meanrD)

    #標準化均值
    arrdd = [0.0]*D
    aved = 0.0
    for i in range(0,D):
        arrdd[i] = arrd[i] -ave
        aved +=arrdd[i]
    aved = aved/D
    print("標準化均值: ",aved)
    
    #匯入資料
    def load_datas():
        datas = list()
        datas.append(
        {
            #匯入編號
            "Number": int(n),
            #匯入名字
            "name": name,
            #匯入影片類別
            "video type": "C",
            #匯入平均
            "average": float(aveD),
            #匯入一階差
            "first order difference":float(diffD1),
            #匯入二階差
            "second order difference":float(diffD2),
            #匯入最大心率
            "max heart":int(scopemaxD),
            #匯入最小心率
            "min heart":int(scopeminD),
            #匯入心率變化範圍
            "max to min scope heart":int(scopeD),
            #匯入資訊熵
            "entropy of information":float(HD),
            #匯入均方根
            "root mean square":float(meanrD),
            #匯入標準化均值
            "standardize average":float(aved),
        }
        )
        return datas

    def create_data(es, datas):
        for data in datas:
            es.index(index='ling-張哲唯01text', body=data)

    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        datas = load_datas()
        create_data(es, datas)
# Out:
# A
# 85
# A
# 73
# A
# 78
# A
# 78
# A
# 86
# [85, 73, 78, 78, 86]
# B
# 74
# B
# 85
# B
# 82
# B
# 76
# B
# 70
# [74, 85, 82, 76, 70]
# C
# 80
# C
# 83
# C
# 77
# C
# 80
# C
# 86
# [80, 83, 77, 80, 86]
# A視頻心率特徵 :
# 平均:  77.4
# 一階差:  6.5
# 二階差:  9.666666666666666
# 最大心率:  85
# 最小心率:  70
# 心率變化範圍:  15
# 資訊熵:  2.321928094887362
# 均方根:  40.4
# 標準化均值:  -2.6
# C視頻心率特徵:
# 平均:  81.2
# 一階差:  4.5
# 二階差:  5.0
# 最大心率:  86
# 最小心率:  77
# 心率變化範圍:  9
# 資訊熵:  2.4506993328423072
# 均方根:  18.0
# 標準化均值:  1.2
# A
# 86
# A
# 74
# A
# 76
# A
# 77
# A
# 78
# [86, 74, 76, 77, 78]
# B
# 75
# B
# 86
# B
# 80
# B
# 73
# B
# 71
# [75, 86, 80, 73, 71]
# C
# 79
# C
# 82
# C
# 76
# C
# 78
# C
# 88
# [79, 82, 76, 78, 88]
# A視頻心率特徵 :
# 平均:  77.0
# 一階差:  6.5
# 二階差:  9.0
# 最大心率:  86
# 最小心率:  71
# 心率變化範圍:  15
# 資訊熵:  2.321928094887362
# 均方根:  42.0
# 標準化均值:  -1.2000000000000028
# C視頻心率特徵:
# 平均:  80.6
# 一階差:  5.25
# 二階差:  6.333333333333333
# 最大心率:  88
# 最小心率:  76
# 心率變化範圍:  12
# 資訊熵:  2.321928094887362
# 均方根:  29.8
# 標準化均值:  2.3999999999999972
# A
# 85
# A
# 75
# A
# 75
# A
# 76
# A
# 77
# [85, 75, 75, 76, 77]
# B
# 73
# B
# 70
# B
# 79
# B
# 72
# B
# 74
# [73, 70, 79, 72, 74]
# C
# 78
# C
# 83
# C
# 75
# C
# 77
# C
# 84
# [78, 83, 75, 77, 84]
# A視頻心率特徵 :
# 平均:  73.6
# 一階差:  5.25
# 二階差:  4.333333333333333
# 最大心率:  79
# 最小心率:  70
# 心率變化範圍:  9
# 資訊熵:  2.321928094887362
# 均方根:  28.6
# 標準化均值:  -3.9999999999999942
# C視頻心率特徵:
# 平均:  79.4
# 一階差:  5.5
# 二階差:  6.0
# 最大心率:  84
# 最小心率:  75
# 心率變化範圍:  9
# 資訊熵:  2.321928094887362
# 均方根:  28.4
# 標準化均值:  1.8000000000000056
# A
# 78
# A
# 74
# A
# 76
# A
# 78
# A
# 76
# [78, 74, 76, 78, 76]
# B
# 74
# B
# 69
# B
# 76
# B
# 72
# B
# 77
# [74, 69, 76, 72, 77]
# C
# 80
# C
# 82
# C
# 77
# C
# 78
# C
# 85
# [80, 82, 77, 78, 85]
# A視頻心率特徵 :
# 平均:  73.6
# 一階差:  5.25
# 二階差:  2.0
# 最大心率:  77
# 最小心率:  69
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  23.0
# 標準化均值:  -2.8000000000000056
# C視頻心率特徵:
# 平均:  80.4
# 一階差:  3.75
# 二階差:  5.0
# 最大心率:  85
# 最小心率:  77
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  15.8
# 標準化均值:  3.9999999999999942
# A
# 77
# A
# 75
# A
# 79
# A
# 79
# A
# 75
# [77, 75, 79, 79, 75]
# B
# 76
# B
# 70
# B
# 77
# B
# 76
# B
# 78
# [76, 70, 77, 76, 78]
# C
# 81
# C
# 81
# C
# 74
# C
# 80
# C
# 84
# [81, 81, 74, 80, 84]
# A視頻心率特徵 :
# 平均:  75.4
# 一階差:  4.0
# 二階差:  2.6666666666666665
# 最大心率:  78
# 最小心率:  70
# 心率變化範圍:  8
# 資訊熵:  2.4506993328423072
# 均方根:  18.0
# 標準化均值:  -1.6
# C視頻心率特徵:
# 平均:  80.0
# 一階差:  4.25
# 二階差:  6.0
# 最大心率:  84
# 最小心率:  74
# 心率變化範圍:  10
# 資訊熵:  2.450699332842307
# 均方根:  20.2
# 標準化均值:  3.0
# A
# 75
# A
# 76
# A
# 78
# A
# 87
# A
# 74
# [75, 76, 78, 87, 74]
# B
# 75
# B
# 71
# B
# 77
# B
# 78
# B
# 79
# [75, 71, 77, 78, 79]
# C
# 82
# C
# 80
# C
# 78
# C
# 81
# C
# 80
# [82, 80, 78, 81, 80]
# A視頻心率特徵 :
# 平均:  76.0
# 一階差:  3.0
# 二階差:  3.6666666666666665
# 最大心率:  79
# 最小心率:  71
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  10.8
# 標準化均值:  -2.0
# C視頻心率特徵:
# 平均:  80.2
# 一階差:  2.0
# 二階差:  2.3333333333333335
# 最大心率:  82
# 最小心率:  78
# 心率變化範圍:  4
# 資訊熵:  2.4506993328423072
# 均方根:  3.6
# 標準化均值:  2.2
# A
# 74
# A
# 77
# A
# 77
# A
# 88
# A
# 73
# [74, 77, 77, 88, 73]
# B
# 74
# B
# 73
# B
# 73
# B
# 77
# B
# 75
# [74, 73, 73, 77, 75]
# C
# 80
# C
# 79
# C
# 80
# C
# 82
# C
# 79
# [80, 79, 80, 82, 79]
# A視頻心率特徵 :
# 平均:  74.4
# 一階差:  1.75
# 二階差:  2.3333333333333335
# 最大心率:  77
# 最小心率:  73
# 心率變化範圍:  4
# 資訊熵:  2.450699332842307
# 均方根:  4.2
# 標準化均值:  -3.3999999999999972
# C視頻心率特徵:
# 平均:  80.0
# 一階差:  1.75
# 二階差:  1.3333333333333333
# 最大心率:  82
# 最小心率:  79
# 心率變化範圍:  3
# 資訊熵:  2.579470570797252
# 均方根:  3.0
# 標準化均值:  2.200000000000003
# A
# 73
# A
# 76
# A
# 78
# A
# 87
# A
# 75
# [73, 76, 78, 87, 75]
# B
# 76
# B
# 72
# B
# 73
# B
# 74
# B
# 76
# [76, 72, 73, 74, 76]
# C
# 81
# C
# 78
# C
# 81
# C
# 80
# C
# 78
# [81, 78, 81, 80, 78]
# A視頻心率特徵 :
# 平均:  74.2
# 一階差:  2.0
# 二階差:  2.6666666666666665
# 最大心率:  76
# 最小心率:  72
# 心率變化範圍:  4
# 資訊熵:  2.4506993328423072
# 均方根:  4.4
# 標準化均值:  -3.599999999999997
# C視頻心率特徵:
# 平均:  79.6
# 一階差:  2.25
# 二階差:  1.6666666666666667
# 最大心率:  81
# 最小心率:  78
# 心率變化範圍:  3
# 資訊熵:  2.579470570797252
# 均方根:  4.6
# 標準化均值:  1.800000000000003
# A
# 72
# A
# 77
# A
# 77
# A
# 88
# A
# 74
# [72, 77, 77, 88, 74]
# B
# 78
# B
# 73
# B
# 74
# B
# 73
# B
# 71
# [78, 73, 74, 73, 71]
# C
# 80
# C
# 81
# C
# 79
# C
# 83
# C
# 81
# [80, 81, 79, 83, 81]
# A視頻心率特徵 :
# 平均:  73.8
# 一階差:  2.25
# 二階差:  2.3333333333333335
# 最大心率:  78
# 最小心率:  71
# 心率變化範圍:  7
# 資訊熵:  2.4506993328423072
# 均方根:  6.2
# 標準化均值:  -3.7999999999999945
# C視頻心率特徵:
# 平均:  80.8
# 一階差:  2.25
# 二階差:  1.6666666666666667
# 最大心率:  83
# 最小心率:  79
# 心率變化範圍:  4
# 資訊熵:  2.4506993328423072
# 均方根:  5.0
# 標準化均值:  3.2000000000000055
# A
# 74
# A
# 79
# A
# 79
# A
# 87
# A
# 75
# [74, 79, 79, 87, 75]
# B
# 84
# B
# 81
# B
# 75
# B
# 69
# B
# 70
# [84, 81, 75, 69, 70]
# C
# 81
# C
# 80
# C
# 81
# C
# 85
# C
# 82
# [81, 80, 81, 85, 82]
# A視頻心率特徵 :
# 平均:  75.8
# 一階差:  4.0
# 二階差:  8.666666666666666
# 最大心率:  84
# 最小心率:  69
# 心率變化範圍:  15
# 資訊熵:  2.321928094887362
# 均方根:  16.4
# 標準化均值:  -2.9999999999999973
# C視頻心率特徵:
# 平均:  81.8
# 一階差:  2.25
# 二階差:  2.0
# 最大心率:  85
# 最小心率:  80
# 心率變化範圍:  5
# 資訊熵:  2.450699332842307
# 均方根:  5.4
# 標準化均值:  3.0000000000000027
# A
# 73
# A
# 78
# A
# 78
# A
# 86
# A
# 76
# [73, 78, 78, 86, 76]
# B
# 85
# B
# 82
# B
# 76
# B
# 70
# B
# 69
# [85, 82, 76, 70, 69]
# C
# 83
# C
# 77
# C
# 80
# C
# 86
# C
# 83
# [83, 77, 80, 86, 83]
# A視頻心率特徵 :
# 平均:  76.4
# 一階差:  4.0
# 二階差:  9.333333333333334
# 最大心率:  85
# 最小心率:  69
# 心率變化範圍:  16
# 資訊熵:  2.321928094887362
# 均方根:  16.4
# 標準化均值:  -1.800000000000003
# C視頻心率特徵:
# 平均:  81.8
# 一階差:  4.5
# 二階差:  5.0
# 最大心率:  86
# 最小心率:  77
# 心率變化範圍:  9
# 資訊熵:  2.4506993328423072
# 均方根:  18.0
# 標準化均值:  3.599999999999997
# A
# 74
# A
# 76
# A
# 77
# A
# 78
# A
# 72
# [74, 76, 77, 78, 72]
# B
# 86
# B
# 80
# B
# 73
# B
# 71
# B
# 72
# [86, 80, 73, 71, 72]
# C
# 82
# C
# 76
# C
# 78
# C
# 88
# C
# 84
# [82, 76, 78, 88, 84]
# A視頻心率特徵 :
# 平均:  76.4
# 一階差:  4.0
# 二階差:  7.666666666666667
# 最大心率:  86
# 最小心率:  71
# 心率變化範圍:  15
# 資訊熵:  2.321928094887362
# 均方根:  18.0
# 標準化均值:  0.9999999999999943
# C視頻心率特徵:
# 平均:  81.6
# 一階差:  5.5
# 二階差:  7.333333333333333
# 最大心率:  88
# 最小心率:  76
# 心率變化範圍:  12
# 資訊熵:  2.321928094887362
# 均方根:  31.2
# 標準化均值:  6.199999999999994
# A
# 75
# A
# 75
# A
# 76
# A
# 77
# A
# 74
# [75, 75, 76, 77, 74]
# B
# 70
# B
# 79
# B
# 72
# B
# 74
# B
# 78
# [70, 79, 72, 74, 78]
# C
# 83
# C
# 75
# C
# 77
# C
# 84
# C
# 85
# [83, 75, 77, 84, 85]
# A視頻心率特徵 :
# 平均:  74.6
# 一階差:  5.5
# 二階差:  4.333333333333333
# 最大心率:  79
# 最小心率:  70
# 心率變化範圍:  9
# 資訊熵:  2.321928094887362
# 均方根:  30.0
# 標準化均值:  -0.8000000000000057
# C視頻心率特徵:
# 平均:  80.8
# 一階差:  4.5
# 二階差:  7.666666666666667
# 最大心率:  85
# 最小心率:  75
# 心率變化範圍:  10
# 資訊熵:  2.321928094887362
# 均方根:  23.6
# 標準化均值:  5.399999999999994
# A
# 74
# A
# 76
# A
# 78
# A
# 76
# A
# 75
# [74, 76, 78, 76, 75]
# B
# 69
# B
# 76
# B
# 72
# B
# 77
# B
# 80
# [69, 76, 72, 77, 80]
# C
# 82
# C
# 77
# C
# 78
# C
# 85
# C
# 82
# [82, 77, 78, 85, 82]
# A視頻心率特徵 :
# 平均:  74.8
# 一階差:  4.75
# 二階差:  4.0
# 最大心率:  80
# 最小心率:  69
# 心率變化範圍:  11
# 資訊熵:  2.321928094887362
# 均方根:  19.8
# 標準化均值:  -0.9999999999999971
# C視頻心率特徵:
# 平均:  80.8
# 一階差:  4.0
# 二階差:  5.333333333333333
# 最大心率:  85
# 最小心率:  77
# 心率變化範圍:  8
# 資訊熵:  2.4506993328423072
# 均方根:  16.8
# 標準化均值:  5.000000000000003
# A
# 75
# A
# 79
# A
# 79
# A
# 75
# A
# 74
# [75, 79, 79, 75, 74]
# B
# 70
# B
# 77
# B
# 76
# B
# 78
# B
# 81
# [70, 77, 76, 78, 81]
# C
# 81
# C
# 74
# C
# 80
# C
# 84
# C
# 81
# [81, 74, 80, 84, 81]
# A視頻心率特徵 :
# 平均:  76.4
# 一階差:  3.25
# 二階差:  4.0
# 最大心率:  81
# 最小心率:  70
# 心率變化範圍:  11
# 資訊熵:  2.321928094887362
# 均方根:  12.6
# 標準化均值:  -5.684341886080802e-15
# C視頻心率特徵:
# 平均:  80.0
# 一階差:  5.0
# 二階差:  4.0
# 最大心率:  84
# 最小心率:  74
# 心率變化範圍:  10
# 資訊熵:  2.4506993328423072
# 均方根:  22.0
# 標準化均值:  3.5999999999999943
# A
# 76
# A
# 78
# A
# 87
# A
# 74
# A
# 75
# [76, 78, 87, 74, 75]
# B
# 71
# B
# 77
# B
# 78
# B
# 79
# B
# 75
# [71, 77, 78, 79, 75]
# C
# 80
# C
# 78
# C
# 81
# C
# 80
# C
# 84
# [80, 78, 81, 80, 84]
# A視頻心率特徵 :
# 平均:  76.0
# 一階差:  3.0
# 二階差:  4.0
# 最大心率:  79
# 最小心率:  71
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  10.8
# 標準化均值:  -2.0
# C視頻心率特徵:
# 平均:  80.6
# 一階差:  2.5
# 二階差:  2.0
# 最大心率:  84
# 最小心率:  78
# 心率變化範圍:  6
# 資訊熵:  2.4506993328423072
# 均方根:  6.0
# 標準化均值:  2.6
# A
# 77
# A
# 77
# A
# 88
# A
# 73
# A
# 77
# [77, 77, 88, 73, 77]
# B
# 73
# B
# 73
# B
# 77
# B
# 75
# B
# 78
# [73, 73, 77, 75, 78]
# C
# 79
# C
# 80
# C
# 82
# C
# 79
# C
# 75
# [79, 80, 82, 79, 75]
# A視頻心率特徵 :
# 平均:  75.2
# 一階差:  2.25
# 二階差:  2.3333333333333335
# 最大心率:  78
# 最小心率:  73
# 心率變化範圍:  5
# 資訊熵:  2.450699332842307
# 均方根:  5.8
# 標準化均值:  -3.2000000000000055
# C視頻心率特徵:
# 平均:  79.0
# 一階差:  2.5
# 二階差:  3.6666666666666665
# 最大心率:  82
# 最小心率:  75
# 心率變化範圍:  7
# 資訊熵:  2.4506993328423072
# 均方根:  6.0
# 標準化均值:  0.5999999999999943
# A
# 76
# A
# 78
# A
# 87
# A
# 75
# A
# 78
# [76, 78, 87, 75, 78]
# B
# 72
# B
# 73
# B
# 74
# B
# 76
# B
# 77
# [72, 73, 74, 76, 77]
# C
# 78
# C
# 81
# C
# 80
# C
# 78
# C
# 78
# [78, 81, 80, 78, 78]
# A視頻心率特徵 :
# 平均:  74.4
# 一階差:  1.25
# 二階差:  2.6666666666666665
# 最大心率:  77
# 最小心率:  72
# 心率變化範圍:  5
# 資訊熵:  2.321928094887362
# 均方根:  1.4
# 標準化均值:  -4.399999999999997
# C視頻心率特徵:
# 平均:  79.0
# 一階差:  1.5
# 二階差:  2.3333333333333335
# 最大心率:  81
# 最小心率:  78
# 心率變化範圍:  3
# 資訊熵:  2.2553093074541164
# 均方根:  2.8
# 標準化均值:  0.20000000000000284
# A
# 77
# A
# 77
# A
# 88
# A
# 74
# A
# 79
# [77, 77, 88, 74, 79]
# B
# 73
# B
# 74
# B
# 73
# B
# 71
# B
# 78
# [73, 74, 73, 71, 78]
# C
# 81
# C
# 79
# C
# 83
# C
# 81
# C
# 79
# [81, 79, 83, 81, 79]
# A視頻心率特徵 :
# 平均:  73.8
# 一階差:  2.75
# 二階差:  2.6666666666666665
# 最大心率:  78
# 最小心率:  71
# 心率變化範圍:  7
# 資訊熵:  2.450699332842307
# 均方根:  11.0
# 標準化均值:  -5.2
# C視頻心率特徵:
# 平均:  80.6
# 一階差:  2.5
# 二階差:  2.6666666666666665
# 最大心率:  83
# 最小心率:  79
# 心率變化範圍:  4
# 資訊熵:  2.579470570797252
# 均方根:  5.6
# 標準化均值:  1.6
# A
# 79
# A
# 79
# A
# 87
# A
# 75
# A
# 80
# [79, 79, 87, 75, 80]
# B
# 81
# B
# 75
# B
# 69
# B
# 70
# B
# 79
# [81, 75, 69, 70, 79]
# C
# 80
# C
# 81
# C
# 85
# C
# 82
# C
# 80
# [80, 81, 85, 82, 80]
# A視頻心率特徵 :
# 平均:  74.8
# 一階差:  5.5
# 二階差:  9.0
# 最大心率:  81
# 最小心率:  69
# 心率變化範圍:  12
# 資訊熵:  2.321928094887362
# 均方根:  30.8
# 標準化均值:  -5.2
# C視頻心率特徵:
# 平均:  81.6
# 一階差:  2.5
# 二階差:  3.6666666666666665
# 最大心率:  85
# 最小心率:  80
# 心率變化範圍:  5
# 資訊熵:  2.4506993328423072
# 均方根:  6.0
# 標準化均值:  1.6
# A
# 78
# A
# 78
# A
# 86
# A
# 76
# A
# 81
# [78, 78, 86, 76, 81]
# B
# 82
# B
# 76
# B
# 70
# B
# 69
# B
# 80
# [82, 76, 70, 69, 80]
# C
# 77
# C
# 80
# C
# 86
# C
# 83
# C
# 83
# [77, 80, 86, 83, 83]
# A視頻心率特徵 :
# 平均:  75.4
# 一階差:  6.0
# 二階差:  9.666666666666666
# 最大心率:  82
# 最小心率:  69
# 心率變化範圍:  13
# 資訊熵:  2.321928094887362
# 均方根:  38.8
# 標準化均值:  -4.399999999999997
# C視頻心率特徵:
# 平均:  81.8
# 一階差:  3.0
# 二階差:  5.0
# 最大心率:  86
# 最小心率:  77
# 心率變化範圍:  9
# 資訊熵:  2.4506993328423072
# 均方根:  10.8
# 標準化均值:  2.0000000000000027
# A
# 76
# A
# 77
# A
# 78
# A
# 72
# A
# 82
# [76, 77, 78, 72, 82]
# B
# 80
# B
# 73
# B
# 71
# B
# 72
# B
# 81
# [80, 73, 71, 72, 81]
# C
# 76
# C
# 78
# C
# 88
# C
# 84
# C
# 87
# [76, 78, 88, 84, 87]
# A視頻心率特徵 :
# 平均:  75.4
# 一階差:  4.75
# 二階差:  6.666666666666667
# 最大心率:  81
# 最小心率:  71
# 心率變化範圍:  10
# 資訊熵:  2.321928094887362
# 均方根:  27.0
# 標準化均值:  -1.6
# C視頻心率特徵:
# 平均:  82.6
# 一階差:  4.75
# 二階差:  6.333333333333333
# 最大心率:  88
# 最小心率:  76
# 心率變化範圍:  12
# 資訊熵:  2.321928094887362
# 均方根:  25.8
# 標準化均值:  5.6
# A
# 75
# A
# 76
# A
# 77
# A
# 74
# A
# 80
# [75, 76, 77, 74, 80]
# B
# 79
# B
# 72
# B
# 74
# B
# 78
# B
# 79
# [79, 72, 74, 78, 79]
# C
# 75
# C
# 77
# C
# 84
# C
# 85
# C
# 84
# [75, 77, 84, 85, 84]
# A視頻心率特徵 :
# 平均:  76.4
# 一階差:  3.5
# 二階差:  5.333333333333333
# 最大心率:  79
# 最小心率:  72
# 心率變化範圍:  7
# 資訊熵:  2.4506993328423072
# 均方根:  14.0
# 標準化均值:  -5.684341886080802e-15
# C視頻心率特徵:
# 平均:  81.0
# 一階差:  2.75
# 二階差:  5.666666666666667
# 最大心率:  85
# 最小心率:  75
# 心率變化範圍:  10
# 資訊熵:  2.4506993328423072
# 均方根:  11.0
# 標準化均值:  4.599999999999994
# A
# 76
# A
# 78
# A
# 76
# A
# 75
# A
# 79
# [76, 78, 76, 75, 79]
# B
# 76
# B
# 72
# B
# 77
# B
# 80
# B
# 73
# [76, 72, 77, 80, 73]
# C
# 77
# C
# 78
# C
# 85
# C
# 82
# C
# 85
# [77, 78, 85, 82, 85]
# A視頻心率特徵 :
# 平均:  75.6
# 一階差:  4.75
# 二階差:  4.333333333333333
# 最大心率:  80
# 最小心率:  72
# 心率變化範圍:  8
# 資訊熵:  2.321928094887362
# 均方根:  19.8
# 標準化均值:  -1.199999999999997
# C視頻心率特徵:
# 平均:  81.4
# 一階差:  3.5
# 二階差:  4.0
# 最大心率:  85
# 最小心率:  77
# 心率變化範圍:  8
# 資訊熵:  2.4506993328423072
# 均方根:  13.6
# 標準化均值:  4.600000000000003
# A
# 79
# A
# 79
# A
# 75
# A
# 74
# A
# 76
# [79, 79, 75, 74, 76]
# B
# 77
# B
# 76
# B
# 78
# B
# 81
# B
# 78
# [77, 76, 78, 81, 78]
# C
# 74
# C
# 80
# C
# 84
# C
# 81
# C
# 86
# [74, 80, 84, 81, 86]
# A視頻心率特徵 :
# 平均:  78.0
# 一階差:  2.25
# 二階差:  2.0
# 最大心率:  81
# 最小心率:  76
# 心率變化範圍:  5
# 資訊熵:  2.4506993328423072
# 均方根:  4.6
# 標準化均值:  1.4000000000000057
# C視頻心率特徵:
# 平均:  81.0
# 一階差:  4.5
# 二階差:  4.333333333333333
# 最大心率:  86
# 最小心率:  74
# 心率變化範圍:  12
# 資訊熵:  2.321928094887362
# 均方根:  17.2
# 標準化均值:  4.400000000000006
