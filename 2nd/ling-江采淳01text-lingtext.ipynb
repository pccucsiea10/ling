# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts='140.137.41.81', port=9200)

# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import metrics
import operator
import math

# %%
#將ling-江采淳數據01的1st進行計算並且將結果傳送到ling-江采淳01text資料庫

from elasticsearch import Elasticsearch
import json

# 正常(feel=naturl)心率取3個為一組
SamplesStartA = 0
SamplesStopA = 30

#A視頻(feel=happy)心率取3個為一組
SamplesStartB = 0
SamplesStopB = 30

#C視頻(feel=sad)心率取3個為一組
SamplesStartC = 0
SamplesStopC = 30

name="江采淳"
trial="3rd"

arra=[0]*3
x=0
arrb=[0]*3
y=0
arrd=[0]*3
z=0

A=3
B=3
D=3

for n in range(0,25): #迴圈取[a1,a11,a21,...],[a2,a22,a33...],[a3,a23,a33...]...共取25組
    arra=[0]*3
    x=0
    arrb=[0]*3
    y=0
    arrd=[0]*3
    z=0
    A=3
    B=3
    D=3
    SamplesStartA+=1
    SamplesStopA+=1
    SamplesStartB+=1
    SamplesStopB+=1
    SamplesStartC+=1
    SamplesStopC+=1
    for m in range(SamplesStartA,SamplesStopA,10):  #迴圈取a1,a11,a21,a31,a41...一組取3個
        def get_queryA():
            queryA = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "name": name
                        }
                    },
                        {
                        "term": {
                            "feel": "natural"
                        }
                    },
                    {
                        "term": {
                            "time": m
                        }
                    },
                        {
                        "term": {
                            "trial": trial
                        }
                    }]
                }
            }
        }
            return queryA
        if __name__ == "__main__":
            es = Elasticsearch(hosts='140.137.41.81', port=9200)
            queryA = get_queryA()
            resultA = es.search(index='ling-江采淳數據01', body=queryA)
            resultaa=json.dumps(resultA, ensure_ascii=False)
            resultPulseA=json.loads(resultaa)
            print("A")
            print(resultPulseA['hits']['hits'][0]['_source']['pulse'])
            aa=resultPulseA['hits']['hits'][0]['_source']['pulse']
            arra[x]=aa
            if x==2:
                print(arra)
                x-=2
            else:
                x+=1
    for p in range(SamplesStartB,SamplesStopB,10):  #迴圈取A視頻心率a1,a11,a21,a31,a41...一組取3個
        def get_queryB():
            queryB = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "name": name
                        }
                    },
                        {
                        "term": {
                            "feel": "happy"
                        }
                    },
                    {
                        "term": {
                            "time": p
                        }
                    },
                        {
                        "term": {
                            "trial": trial
                        }
                    }]
                }
            }
        }
            return queryB
        if __name__ == "__main__":
            es = Elasticsearch(hosts='140.137.41.81', port=9200)
            queryB = get_queryB()
            resultB = es.search(index='ling-江采淳數據01', body=queryB)
            resultbb=json.dumps(resultB, ensure_ascii=False)
            resultPulseB=json.loads(resultbb)
            print("B")
            print(resultPulseB['hits']['hits'][0]['_source']['pulse'])
            bb=resultPulseB['hits']['hits'][0]['_source']['pulse']
            arrb[y]=bb
            if y==2:
                print(arrb)
                y-=2
            else:
                y+=1
    for q in range(SamplesStartC,SamplesStopC,10):     #迴圈取C視頻心率a1,a11,a21,a31,a41...一組取3個
        def get_queryC():
            queryC = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "name": name
                        }
                    },
                        {
                        "term": {
                            "feel": "sad"
                        }
                    },
                    {
                        "term": {
                            "time": q
                        }
                    },
                        {
                        "term": {
                            "trial": trial
                        }
                    }]
                }
            }
        }
            return queryC
        if __name__ == "__main__":
            es = Elasticsearch(hosts='140.137.41.81', port=9200)
            queryC = get_queryC()
            resultC = es.search(index='ling-江采淳數據01', body=queryC)
            resultcc=json.dumps(resultC, ensure_ascii=False)
            resultPulseC=json.loads(resultcc)
            print("C")
            print(resultPulseC['hits']['hits'][0]['_source']['pulse'])
            cc=resultPulseC['hits']['hits'][0]['_source']['pulse']
            arrd[z]=cc
            if z==2:
                print(arrd)
                z-=2
            else:
                z+=1
    #正常心率平均
    ave = 0.0
    for i in range(0,A):
        ave+=arra[i]
    ave = ave/A

    print("A視頻心率特徵 :")

    #平均
    aveB = 0.0
    for i in range(0,B):
        aveB +=arrb[i]
    aveB = aveB/B
    print("平均: ",aveB)

    #DiffB1 一階差的平均值
    diffB1 = 0.0
    meanB1 = 0.0
    #X[n-1]-X[n]的總和
    for i in range(0,(B-1)):
        meanB1+=abs(arrb[i+1]-arrb[i])
    diffB1 = meanB1/(B-1)
    print("一階差: ",diffB1)

    #DiffB2 二階差的平均值
    diffB2 = 0.0
    meanB2 = 0.0
    #X[n+2]-X[n]的總和
    for i in range(0,(B-2)):
        meanB2 += abs(arrb[i+2]-arrb[i])
    diffB2 = meanB2/(B-2)
    print("二階差: ",diffB2)

    #range 心率變化範圍
    scopeB = 0
    scopemaxB = 0
    scopeminB = 110
    for i in range(0,B):
        #求最大心率
        if arrb[i]>scopemaxB:
            scopemaxB = arrb[i]
        if arrb[i]<scopeminB:
            scopeminB = arrb[i]
    scopeB = scopemaxB-scopeminB
    print("最大心率: ",scopemaxB)
    print("最小心率: ",scopeminB)
    print("心率變化範圍: ",scopeB)

    #H(X)資訊熵
    x = 0
    HB = 0
    arrpb = [0.0]*B
    for i in range(0,B):
        x=0 #初值為0
        #心率出現次數
        for j in range(0,B):
            if arrb[i]==arrb[j]:
                x+=1
        #p[i]機率
        arrpb[i] = x*1.0/B
    for k in range(0,B):
        HB += -arrpb[k]*math.log(arrpb[k],2)
    print("資訊熵: ",HB)

    #Radrm 均方根
    radrmB = 0.0   
    meanrB = 0.0
    #相鄰值平方差的總和
    for i in range(0,(B-1)):
        radrmB += pow(arrb[i+1]-arrb[i],2)
    meanrB = radrmB/B
    print("均方根: ",meanrB)

    #標準化均值
    arrbb=[0.0]*B
    aveb = 0.0
    for i in range(0,B):
        arrbb[i] = arrb[i]-ave
        aveb += arrbb[i]
    aveb = aveb/B
    print("標準化均值: ",aveb)
    def load_datas():
        datas = list()
        datas.append(
        {
            #匯入編號
            "Number": int(n),
            #匯入名字
            "name": name,
            #匯入實驗次數
            "trial":trial,
            #匯入影片類別
            "video type": "A",
            #匯入平均
            "average": float(aveB),
            #匯入一階差
            "first order difference":float(diffB1),
            #匯入二階差
            "second order difference":float(diffB2),
            #匯入最大心率
            "max heart":int(scopemaxB),
            #匯入最小心率
            "min heart":int(scopeminB),
            #匯入心率變化範圍
            "max to min scope heart":int(scopeB),
            #匯入資訊熵
            "entropy of information":float(HB),
            #匯入均方根
            "root mean square":float(meanrB),
            #匯入標準化均值
            "standardize average":float(aveb),
        }
        )
        return datas

    def create_data(es, datas):
        for data in datas:
            es.index(index='ling-text', body=data)

    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        datas = load_datas()
        create_data(es, datas)
    print("C視頻心率特徵: ")

    #平均
    aveD = 0.0
    for i in range(0,D):
        aveD +=arrd[i]
    aveD = aveD/D
    print("平均: ",aveD)

    #DiffD1 一階差的平均值
    diffD1 = 0.0
    meanD1 = 0.0
    #X[n+1]-X[n]的總和
    for i in range(0,(D-1)):
        meanD1 += abs(arrd[i+1]-arrd[i])
    diffD1 = meanD1/(D-1)
    print("一階差: ",diffD1)

    #DiffD2 二階差的平均值
    diffD2 = 0.0
    meanD2 = 0.0
    #X[n+2]-X[n]的總和
    for i in range(0,(D-2)):
        meanD2 += abs(arrd[i+2]-arrd[i])
    diffD2 = meanD2/(D-2)
    print("二階差: ",diffD2)

    #range 心率變化範圍
    scopeD = 0
    scopemaxD = 0
    scopeminD = 110
    for i in range(0,D):
        #求最大心率
        if arrd[i]>scopemaxD:
            scopemaxD = arrd[i]
        #求最小心率
        if arrd[i]<scopeminD:
            scopeminD = arrd[i]
    scopeD = scopemaxD-scopeminD
    print("最大心率: ",scopemaxD)
    print("最小心率: ",scopeminD)
    print("心率變化範圍: ",scopeD)

    #H(X)資訊熵
    x = 0
    HD = 0
    arrpd = [0.0]*D
    for i in range(0,D):
        x = 0 #初值為0 
        #心率出現次數
        for j in range(0,D):
            if arrd[i]==arrd[j]:
                x+=1
        arrpd[i] = x*1.0/D
    for k in range(0,D):
        HD += -arrpd[k]*math.log(arrpd[k],2)
    print("資訊熵: ",HD)

    #Radrm 均方根
    radrmD = 0.0
    meanrD = 0.0
    #相鄰值平方差的總和
    for i in range(0,(D-1)):
        radrmD += pow(arrd[i+1]-arrd[i],2)
    meanrD = radrmD/D
    print("均方根: ",meanrD)

    #標準化均值
    arrdd = [0.0]*D
    aved = 0.0
    for i in range(0,D):
        arrdd[i] = arrd[i] -ave
        aved +=arrdd[i]
    aved = aved/D
    print("標準化均值: ",aved)
    
    #匯入資料
    def load_datas():
        datas = list()
        datas.append(
        {
            #匯入編號
            "Number": int(n),
            #匯入名字
            "name": name,
            #匯入實驗次數
            "trial":trial,
            #匯入影片類別
            "video type": "C",
            #匯入平均
            "average": float(aveD),
            #匯入一階差
            "first order difference":float(diffD1),
            #匯入二階差
            "second order difference":float(diffD2),
            #匯入最大心率
            "max heart":int(scopemaxD),
            #匯入最小心率
            "min heart":int(scopeminD),
            #匯入心率變化範圍
            "max to min scope heart":int(scopeD),
            #匯入資訊熵
            "entropy of information":float(HD),
            #匯入均方根
            "root mean square":float(meanrD),
            #匯入標準化均值
            "standardize average":float(aved),
        }
        )
        return datas

    def create_data(es, datas):
        for data in datas:
            es.index(index='ling-text', body=data)

    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        datas = load_datas()
        create_data(es, datas)
# Out:
# A
# 86
# A
# 88
# A
# 85
# [86, 88, 85]
# B
# 85
# B
# 80
# B
# 86
# [85, 80, 86]
# C
# 80
# C
# 75
# C
# 72
# [80, 75, 72]
# A視頻心率特徵 :
# 平均:  83.66666666666667
# 一階差:  5.5
# 二階差:  1.0
# 最大心率:  86
# 最小心率:  80
# 心率變化範圍:  6
# 資訊熵:  1.584962500721156
# 均方根:  20.333333333333332
# 標準化均值:  -2.666666666666662
# C視頻心率特徵:
# 平均:  75.66666666666667
# 一階差:  4.0
# 二階差:  8.0
# 最大心率:  80
# 最小心率:  72
# 心率變化範圍:  8
# 資訊熵:  1.584962500721156
# 均方根:  11.333333333333334
# 標準化均值:  -10.666666666666663
# A
# 88
# A
# 87
# A
# 84
# [88, 87, 84]
# B
# 86
# B
# 81
# B
# 83
# [86, 81, 83]
# C
# 79
# C
# 80
# C
# 74
# [79, 80, 74]
# A視頻心率特徵 :
# 平均:  83.33333333333333
# 一階差:  3.5
# 二階差:  3.0
# 最大心率:  86
# 最小心率:  81
# 心率變化範圍:  5
# 資訊熵:  1.584962500721156
# 均方根:  9.666666666666666
# 標準化均值:  -2.999999999999995
# C視頻心率特徵:
# 平均:  77.66666666666667
# 一階差:  3.5
# 二階差:  5.0
# 最大心率:  80
# 最小心率:  74
# 心率變化範圍:  6
# 資訊熵:  1.584962500721156
# 均方根:  12.333333333333334
# 標準化均值:  -8.666666666666663
# A
# 89
# A
# 86
# A
# 83
# [89, 86, 83]
# B
# 87
# B
# 82
# B
# 81
# [87, 82, 81]
# C
# 81
# C
# 81
# C
# 73
# [81, 81, 73]
# A視頻心率特徵 :
# 平均:  83.33333333333333
# 一階差:  3.0
# 二階差:  6.0
# 最大心率:  87
# 最小心率:  81
# 心率變化範圍:  6
# 資訊熵:  1.584962500721156
# 均方根:  8.666666666666666
# 標準化均值:  -2.6666666666666665
# C視頻心率特徵:
# 平均:  78.33333333333333
# 一階差:  4.0
# 二階差:  8.0
# 最大心率:  81
# 最小心率:  73
# 心率變化範圍:  8
# 資訊熵:  1.3082708345352603
# 均方根:  21.333333333333332
# 標準化均值:  -7.666666666666667
# A
# 90
# A
# 85
# A
# 82
# [90, 85, 82]
# B
# 86
# B
# 88
# B
# 82
# [86, 88, 82]
# C
# 78
# C
# 71
# C
# 75
# [78, 71, 75]
# A視頻心率特徵 :
# 平均:  85.33333333333333
# 一階差:  4.0
# 二階差:  4.0
# 最大心率:  88
# 最小心率:  82
# 心率變化範圍:  6
# 資訊熵:  1.584962500721156
# 均方根:  13.333333333333334
# 標準化均值:  -0.3333333333333381
# C視頻心率特徵:
# 平均:  74.66666666666667
# 一階差:  5.5
# 二階差:  3.0
# 最大心率:  78
# 最小心率:  71
# 心率變化範圍:  7
# 資訊熵:  1.584962500721156
# 均方根:  21.666666666666668
# 標準化均值:  -11.000000000000005
# A
# 92
# A
# 84
# A
# 83
# [92, 84, 83]
# B
# 87
# B
# 90
# B
# 81
# [87, 90, 81]
# C
# 77
# C
# 70
# C
# 76
# [77, 70, 76]
# A視頻心率特徵 :
# 平均:  86.0
# 一階差:  6.0
# 二階差:  6.0
# 最大心率:  90
# 最小心率:  81
# 心率變化範圍:  9
# 資訊熵:  1.584962500721156
# 均方根:  30.0
# 標準化均值:  -0.3333333333333286
# C視頻心率特徵:
# 平均:  74.33333333333333
# 一階差:  6.5
# 二階差:  1.0
# 最大心率:  77
# 最小心率:  70
# 心率變化範圍:  7
# 資訊熵:  1.584962500721156
# 均方根:  28.333333333333332
# 標準化均值:  -11.999999999999995
# A
# 93
# A
# 87
# A
# 87
# [93, 87, 87]
# B
# 86
# B
# 91
# B
# 83
# [86, 91, 83]
# C
# 76
# C
# 68
# C
# 74
# [76, 68, 74]
# A視頻心率特徵 :
# 平均:  86.66666666666667
# 一階差:  6.5
# 二階差:  3.0
# 最大心率:  91
# 最小心率:  83
# 心率變化範圍:  8
# 資訊熵:  1.584962500721156
# 均方根:  29.666666666666668
# 標準化均值:  -2.3333333333333335
# C視頻心率特徵:
# 平均:  72.66666666666667
# 一階差:  7.0
# 二階差:  2.0
# 最大心率:  76
# 最小心率:  68
# 心率變化範圍:  8
# 資訊熵:  1.584962500721156
# 均方根:  33.333333333333336
# 標準化均值:  -16.333333333333332
# A
# 91
# A
# 88
# A
# 88
# [91, 88, 88]
# B
# 82
# B
# 93
# B
# 82
# [82, 93, 82]
# C
# 74
# C
# 66
# C
# 75
# [74, 66, 75]
# A視頻心率特徵 :
# 平均:  85.66666666666667
# 一階差:  11.0
# 二階差:  0.0
# 最大心率:  93
# 最小心率:  82
# 心率變化範圍:  11
# 資訊熵:  1.3082708345352603
# 均方根:  80.66666666666667
# 標準化均值:  -3.3333333333333335
# C視頻心率特徵:
# 平均:  71.66666666666667
# 一階差:  8.5
# 二階差:  1.0
# 最大心率:  75
# 最小心率:  66
# 心率變化範圍:  9
# 資訊熵:  1.584962500721156
# 均方根:  48.333333333333336
# 標準化均值:  -17.333333333333332
# A
# 90
# A
# 87
# A
# 87
# [90, 87, 87]
# B
# 81
# B
# 94
# B
# 83
# [81, 94, 83]
# C
# 72
# C
# 67
# C
# 72
# [72, 67, 72]
# A視頻心率特徵 :
# 平均:  86.0
# 一階差:  12.0
# 二階差:  2.0
# 最大心率:  94
# 最小心率:  81
# 心率變化範圍:  13
# 資訊熵:  1.584962500721156
# 均方根:  96.66666666666667
# 標準化均值:  -2.0
# C視頻心率特徵:
# 平均:  70.33333333333333
# 一階差:  5.0
# 二階差:  0.0
# 最大心率:  72
# 最小心率:  67
# 心率變化範圍:  5
# 資訊熵:  1.3082708345352603
# 均方根:  16.666666666666668
# 標準化均值:  -17.666666666666668
# A
# 92
# A
# 86
# A
# 88
# [92, 86, 88]
# B
# 78
# B
# 93
# B
# 84
# [78, 93, 84]
# C
# 71
# C
# 66
# C
# 80
# [71, 66, 80]
# A視頻心率特徵 :
# 平均:  85.0
# 一階差:  12.0
# 二階差:  6.0
# 最大心率:  93
# 最小心率:  78
# 心率變化範圍:  15
# 資訊熵:  1.584962500721156
# 均方根:  102.0
# 標準化均值:  -3.6666666666666714
# C視頻心率特徵:
# 平均:  72.33333333333333
# 一階差:  9.5
# 二階差:  9.0
# 最大心率:  80
# 最小心率:  66
# 心率變化範圍:  14
# 資訊熵:  1.584962500721156
# 均方根:  73.66666666666667
# 標準化均值:  -16.33333333333334
# A
# 89
# A
# 87
# A
# 84
# [89, 87, 84]
# B
# 77
# B
# 87
# B
# 83
# [77, 87, 83]
# C
# 73
# C
# 68
# C
# 83
# [73, 68, 83]
# A視頻心率特徵 :
# 平均:  82.33333333333333
# 一階差:  7.0
# 二階差:  6.0
# 最大心率:  87
# 最小心率:  77
# 心率變化範圍:  10
# 資訊熵:  1.584962500721156
# 均方根:  38.666666666666664
# 標準化均值:  -4.333333333333338
# C視頻心率特徵:
# 平均:  74.66666666666667
# 一階差:  10.0
# 二階差:  10.0
# 最大心率:  83
# 最小心率:  68
# 心率變化範圍:  15
# 資訊熵:  1.584962500721156
# 均方根:  83.33333333333333
# 標準化均值:  -12.000000000000005
# A
# 88
# A
# 85
# A
# 82
# [88, 85, 82]
# B
# 80
# B
# 86
# B
# 82
# [80, 86, 82]
# C
# 75
# C
# 72
# C
# 84
# [75, 72, 84]
# A視頻心率特徵 :
# 平均:  82.66666666666667
# 一階差:  5.0
# 二階差:  2.0
# 最大心率:  86
# 最小心率:  80
# 心率變化範圍:  6
# 資訊熵:  1.584962500721156
# 均方根:  17.333333333333332
# 標準化均值:  -2.3333333333333335
# C視頻心率特徵:
# 平均:  77.0
# 一階差:  7.5
# 二階差:  9.0
# 最大心率:  84
# 最小心率:  72
# 心率變化範圍:  12
# 資訊熵:  1.584962500721156
# 均方根:  51.0
# 標準化均值:  -8.0
# A
# 87
# A
# 84
# A
# 84
# [87, 84, 84]
# B
# 81
# B
# 83
# B
# 81
# [81, 83, 81]
# C
# 80
# C
# 74
# C
# 85
# [80, 74, 85]
# A視頻心率特徵 :
# 平均:  81.66666666666667
# 一階差:  2.0
# 二階差:  0.0
# 最大心率:  83
# 最小心率:  81
# 心率變化範圍:  2
# 資訊熵:  1.3082708345352603
# 均方根:  2.6666666666666665
# 標準化均值:  -3.3333333333333335
# C視頻心率特徵:
# 平均:  79.66666666666667
# 一階差:  8.5
# 二階差:  5.0
# 最大心率:  85
# 最小心率:  74
# 心率變化範圍:  11
# 資訊熵:  1.584962500721156
# 均方根:  52.333333333333336
# 標準化均值:  -5.333333333333333
# A
# 86
# A
# 83
# A
# 83
# [86, 83, 83]
# B
# 82
# B
# 81
# B
# 82
# [82, 81, 82]
# C
# 81
# C
# 73
# C
# 86
# [81, 73, 86]
# A視頻心率特徵 :
# 平均:  81.66666666666667
# 一階差:  1.0
# 二階差:  0.0
# 最大心率:  82
# 最小心率:  81
# 心率變化範圍:  1
# 資訊熵:  1.3082708345352603
# 均方根:  0.6666666666666666
# 標準化均值:  -2.3333333333333335
# C視頻心率特徵:
# 平均:  80.0
# 一階差:  10.5
# 二階差:  5.0
# 最大心率:  86
# 最小心率:  73
# 心率變化範圍:  13
# 資訊熵:  1.584962500721156
# 均方根:  77.66666666666667
# 標準化均值:  -4.0
# A
# 85
# A
# 82
# A
# 86
# [85, 82, 86]
# B
# 88
# B
# 82
# B
# 83
# [88, 82, 83]
# C
# 71
# C
# 75
# C
# 84
# [71, 75, 84]
# A視頻心率特徵 :
# 平均:  84.33333333333333
# 一階差:  3.5
# 二階差:  5.0
# 最大心率:  88
# 最小心率:  82
# 心率變化範圍:  6
# 資訊熵:  1.584962500721156
# 均方根:  12.333333333333334
# 標準化均值:  4.736951571734001e-15
# C視頻心率特徵:
# 平均:  76.66666666666667
# 一階差:  6.5
# 二階差:  13.0
# 最大心率:  84
# 最小心率:  71
# 心率變化範圍:  13
# 資訊熵:  1.584962500721156
# 均方根:  32.333333333333336
# 標準化均值:  -7.666666666666662
# A
# 84
# A
# 83
# A
# 87
# [84, 83, 87]
# B
# 90
# B
# 81
# B
# 83
# [90, 81, 83]
# C
# 70
# C
# 76
# C
# 82
# [70, 76, 82]
# A視頻心率特徵 :
# 平均:  84.66666666666667
# 一階差:  5.5
# 二階差:  7.0
# 最大心率:  90
# 最小心率:  81
# 心率變化範圍:  9
# 資訊熵:  1.584962500721156
# 均方根:  28.333333333333332
# 標準化均值:  -4.736951571734001e-15
# C視頻心率特徵:
# 平均:  76.0
# 一階差:  6.0
# 二階差:  12.0
# 最大心率:  82
# 最小心率:  70
# 心率變化範圍:  12
# 資訊熵:  1.584962500721156
# 均方根:  24.0
# 標準化均值:  -8.666666666666671
# A
# 87
# A
# 87
# A
# 88
# [87, 87, 88]
# B
# 91
# B
# 83
# B
# 82
# [91, 83, 82]
# C
# 68
# C
# 74
# C
# 81
# [68, 74, 81]
# A視頻心率特徵 :
# 平均:  85.33333333333333
# 一階差:  4.5
# 二階差:  9.0
# 最大心率:  91
# 最小心率:  82
# 心率變化範圍:  9
# 資訊熵:  1.584962500721156
# 均方根:  21.666666666666668
# 標準化均值:  -1.9999999999999953
# C視頻心率特徵:
# 平均:  74.33333333333333
# 一階差:  6.5
# 二階差:  13.0
# 最大心率:  81
# 最小心率:  68
# 心率變化範圍:  13
# 資訊熵:  1.584962500721156
# 均方根:  28.333333333333332
# 標準化均值:  -12.999999999999995
# A
# 88
# A
# 88
# A
# 89
# [88, 88, 89]
# B
# 93
# B
# 82
# B
# 81
# [93, 82, 81]
# C
# 66
# C
# 75
# C
# 80
# [66, 75, 80]
# A視頻心率特徵 :
# 平均:  85.33333333333333
# 一階差:  6.0
# 二階差:  12.0
# 最大心率:  93
# 最小心率:  81
# 心率變化範圍:  12
# 資訊熵:  1.584962500721156
# 均方根:  40.666666666666664
# 標準化均值:  -2.999999999999995
# C視頻心率特徵:
# 平均:  73.66666666666667
# 一階差:  7.0
# 二階差:  14.0
# 最大心率:  80
# 最小心率:  66
# 心率變化範圍:  14
# 資訊熵:  1.584962500721156
# 均方根:  35.333333333333336
# 標準化均值:  -14.666666666666663
# A
# 87
# A
# 87
# A
# 90
# [87, 87, 90]
# B
# 94
# B
# 83
# B
# 80
# [94, 83, 80]
# C
# 67
# C
# 72
# C
# 79
# [67, 72, 79]
# A視頻心率特徵 :
# 平均:  85.66666666666667
# 一階差:  7.0
# 二階差:  14.0
# 最大心率:  94
# 最小心率:  80
# 心率變化範圍:  14
# 資訊熵:  1.584962500721156
# 均方根:  43.333333333333336
# 標準化均值:  -2.3333333333333335
# C視頻心率特徵:
# 平均:  72.66666666666667
# 一階差:  6.0
# 二階差:  12.0
# 最大心率:  79
# 最小心率:  67
# 心率變化範圍:  12
# 資訊熵:  1.584962500721156
# 均方根:  24.666666666666668
# 標準化均值:  -15.333333333333334
# A
# 86
# A
# 88
# A
# 87
# [86, 88, 87]
# B
# 93
# B
# 84
# B
# 79
# [93, 84, 79]
# C
# 66
# C
# 80
# C
# 80
# [66, 80, 80]
# A視頻心率特徵 :
# 平均:  85.33333333333333
# 一階差:  7.0
# 二階差:  14.0
# 最大心率:  93
# 最小心率:  79
# 心率變化範圍:  14
# 資訊熵:  1.584962500721156
# 均方根:  35.333333333333336
# 標準化均值:  -1.6666666666666667
# C視頻心率特徵:
# 平均:  75.33333333333333
# 一階差:  7.0
# 二階差:  14.0
# 最大心率:  80
# 最小心率:  66
# 心率變化範圍:  14
# 資訊熵:  1.3082708345352603
# 均方根:  65.33333333333333
# 標準化均值:  -11.666666666666666
# A
# 87
# A
# 84
# A
# 86
# [87, 84, 86]
# B
# 87
# B
# 83
# B
# 95
# [87, 83, 95]
# C
# 68
# C
# 83
# C
# 82
# [68, 83, 82]
# A視頻心率特徵 :
# 平均:  88.33333333333333
# 一階差:  8.0
# 二階差:  8.0
# 最大心率:  95
# 最小心率:  83
# 心率變化範圍:  12
# 資訊熵:  1.584962500721156
# 均方根:  53.333333333333336
# 標準化均值:  2.666666666666662
# C視頻心率特徵:
# 平均:  77.66666666666667
# 一階差:  8.0
# 二階差:  14.0
# 最大心率:  83
# 最小心率:  68
# 心率變化範圍:  15
# 資訊熵:  1.584962500721156
# 均方根:  75.33333333333333
# 標準化均值:  -8.000000000000005
# A
# 85
# A
# 82
# A
# 84
# [85, 82, 84]
# B
# 86
# B
# 82
# B
# 91
# [86, 82, 91]
# C
# 72
# C
# 84
# C
# 80
# [72, 84, 80]
# A視頻心率特徵 :
# 平均:  86.33333333333333
# 一階差:  6.5
# 二階差:  5.0
# 最大心率:  91
# 最小心率:  82
# 心率變化範圍:  9
# 資訊熵:  1.584962500721156
# 均方根:  32.333333333333336
# 標準化均值:  2.666666666666662
# C視頻心率特徵:
# 平均:  78.66666666666667
# 一階差:  8.0
# 二階差:  8.0
# 最大心率:  84
# 最小心率:  72
# 心率變化範圍:  12
# 資訊熵:  1.584962500721156
# 均方根:  53.333333333333336
# 標準化均值:  -5.000000000000004
# A
# 84
# A
# 84
# A
# 86
# [84, 84, 86]
# B
# 83
# B
# 81
# B
# 89
# [83, 81, 89]
# C
# 74
# C
# 85
# C
# 79
# [74, 85, 79]
# A視頻心率特徵 :
# 平均:  84.33333333333333
# 一階差:  5.0
# 二階差:  6.0
# 最大心率:  89
# 最小心率:  81
# 心率變化範圍:  8
# 資訊熵:  1.584962500721156
# 均方根:  22.666666666666668
# 標準化均值:  -0.3333333333333381
# C視頻心率特徵:
# 平均:  79.33333333333333
# 一階差:  8.5
# 二階差:  5.0
# 最大心率:  85
# 最小心率:  74
# 心率變化範圍:  11
# 資訊熵:  1.584962500721156
# 均方根:  52.333333333333336
# 標準化均值:  -5.333333333333338
# A
# 83
# A
# 83
# A
# 83
# [83, 83, 83]
# B
# 81
# B
# 82
# B
# 88
# [81, 82, 88]
# C
# 73
# C
# 86
# C
# 78
# [73, 86, 78]
# A視頻心率特徵 :
# 平均:  83.66666666666667
# 一階差:  3.5
# 二階差:  7.0
# 最大心率:  88
# 最小心率:  81
# 心率變化範圍:  7
# 資訊熵:  1.584962500721156
# 均方根:  12.333333333333334
# 標準化均值:  0.6666666666666666
# C視頻心率特徵:
# 平均:  79.0
# 一階差:  10.5
# 二階差:  5.0
# 最大心率:  86
# 最小心率:  73
# 心率變化範圍:  13
# 資訊熵:  1.584962500721156
# 均方根:  77.66666666666667
# 標準化均值:  -4.0
# A
# 82
# A
# 86
# A
# 85
# [82, 86, 85]
# B
# 82
# B
# 83
# B
# 87
# [82, 83, 87]
# C
# 75
# C
# 84
# C
# 89
# [75, 84, 89]
# A視頻心率特徵 :
# 平均:  84.0
# 一階差:  2.5
# 二階差:  5.0
# 最大心率:  87
# 最小心率:  82
# 心率變化範圍:  5
# 資訊熵:  1.584962500721156
# 均方根:  5.666666666666667
# 標準化均值:  -0.3333333333333286
# C視頻心率特徵:
# 平均:  82.66666666666667
# 一階差:  7.0
# 二階差:  14.0
# 最大心率:  89
# 最小心率:  75
# 心率變化範圍:  14
# 資訊熵:  1.584962500721156
# 均方根:  35.333333333333336
# 標準化均值:  -1.6666666666666619
# A
# 83
# A
# 87
# A
# 86
# [83, 87, 86]
# B
# 81
# B
# 83
# B
# 86
# [81, 83, 86]
# C
# 76
# C
# 82
# C
# 86
# [76, 82, 86]
# A視頻心率特徵 :
# 平均:  83.33333333333333
# 一階差:  2.5
# 二階差:  5.0
# 最大心率:  86
# 最小心率:  81
# 心率變化範圍:  5
# 資訊熵:  1.584962500721156
# 均方根:  4.333333333333333
# 標準化均值:  -1.9999999999999953
# C視頻心率特徵:
# 平均:  81.33333333333333
# 一階差:  5.0
# 二階差:  10.0
# 最大心率:  86
# 最小心率:  76
# 心率變化範圍:  10
# 資訊熵:  1.584962500721156
# 均方根:  17.333333333333332
# 標準化均值:  -3.999999999999995
