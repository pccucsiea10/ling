# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts='140.137.41.81', port=9200)

# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import metrics
import operator
import math

# %%
from elasticsearch import Elasticsearch
import json
arrX1=[0.0]*50
for a in range(0,25): 
    def get_queryX1():
        queryX1 = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "Number": a
                        }
                    },
                        {
                        "term": {
                            "name": "張哲唯"
                        }
                    },
                    {
                        "term": {
                            "video type": "A"
                        }
                    }]
                }
            }
        }
        return queryX1
    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        queryX1 = get_queryX1()
        resultX1 = es.search(index='ling-張哲唯01text', body=queryX1)
        resultxx1=json.dumps(resultX1, ensure_ascii=False)
        resultPulseX1=json.loads(resultxx1)
        X1=resultPulseX1['hits']['hits'][0]['_source']['average']
        arrX1[a]=X1
for b in range(0,25): 
    def get_queryX1():
        queryX1 = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "Number": b
                        }
                    },
                        {
                        "term": {
                            "name": "張哲唯"
                        }
                    },
                    {
                        "term": {
                            "video type": "C"
                        }
                    }]
                }
            }
        }
        return queryX1
    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        queryX1 = get_queryX1()
        resultX1 = es.search(index='ling-張哲唯01text', body=queryX1)
        resultxx1=json.dumps(resultX1, ensure_ascii=False)
        resultPulseX1=json.loads(resultxx1)
        X1=resultPulseX1['hits']['hits'][0]['_source']['average']
        arrX1[b+25]=X1
print("arrX1=",arrX1)
arrX2=[0.0]*50
for c in range(0,25): 
    def get_queryX2():
        queryX2 = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "Number": c
                        }
                    },
                        {
                        "term": {
                            "name": "張哲唯"
                        }
                    },
                    {
                        "term": {
                            "video type": "A"
                        }
                    }]
                }
            }
        }
        return queryX2
    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        queryX2 = get_queryX2()
        resultX2 = es.search(index='ling-張哲唯01text', body=queryX2)
        resultxx2=json.dumps(resultX2, ensure_ascii=False)
        resultPulseX2=json.loads(resultxx2)
        X2=resultPulseX2['hits']['hits'][0]['_source']['first order difference']
        arrX2[c]=X2
for d in range(0,25): 
    def get_queryX2():
        queryX2 = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "Number": d
                        }
                    },
                        {
                        "term": {
                            "name": "張哲唯"
                        }
                    },
                    {
                        "term": {
                            "video type": "C"
                        }
                    }]
                }
            }
        }
        return queryX2
    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        queryX2 = get_queryX2()
        resultX2 = es.search(index='ling-張哲唯01text', body=queryX2)
        resultxx2=json.dumps(resultX2, ensure_ascii=False)
        resultPulseX2=json.loads(resultxx2)
        X2=resultPulseX2['hits']['hits'][0]['_source']['first order difference']
        arrX2[d+25]=X2
print("arrX2=",arrX2)
arrX3=[0.0]*50
for e in range(0,25): 
    def get_queryX3():
        queryX3 = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "Number": e
                        }
                    },
                        {
                        "term": {
                            "name": "張哲唯"
                        }
                    },
                    {
                        "term": {
                            "video type": "A"
                        }
                    }]
                }
            }
        }
        return queryX3
    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        queryX3 = get_queryX3()
        resultX3 = es.search(index='ling-張哲唯01text', body=queryX3)
        resultxx3=json.dumps(resultX3, ensure_ascii=False)
        resultPulseX3=json.loads(resultxx3)
        X3=resultPulseX3['hits']['hits'][0]['_source']['second order difference']
        arrX3[e]=X3
for f in range(0,25): 
    def get_queryX2():
        queryX2 = {
            "query": {
                "bool": {
                    "must": [{
                        "term": {
                            "Number": d
                        }
                    },
                        {
                        "term": {
                            "name": "張哲唯"
                        }
                    },
                    {
                        "term": {
                            "video type": "C"
                        }
                    }]
                }
            }
        }
        return queryX2
    if __name__ == "__main__":
        es = Elasticsearch(hosts='140.137.41.81', port=9200)
        queryX2 = get_queryX2()
        resultX2 = es.search(index='ling-張哲唯01text', body=queryX2)
        resultxx2=json.dumps(resultX2, ensure_ascii=False)
        resultPulseX2=json.loads(resultxx2)
        X2=resultPulseX2['hits']['hits'][0]['_source']['first order difference']
        arrX2[d+25]=X2
print("arrX2=",arrX2)
# Out:
# arrX1= [77.4, 77.0, 73.6, 73.6, 75.4, 76.0, 74.4, 74.2, 73.8, 75.8, 76.4, 76.4, 74.6, 74.8, 76.4, 76.0, 75.2, 74.4, 73.8, 74.8, 75.4, 75.4, 76.4, 75.6, 78.0, 81.2, 80.6, 79.4, 80.4, 80.0, 80.2, 80.0, 79.6, 80.8, 81.8, 81.8, 81.6, 80.8, 80.8, 80.0, 80.6, 79.0, 79.0, 80.6, 81.6, 81.8, 82.6, 81.0, 81.4, 81.0]
# arrX2= [6.5, 6.5, 5.25, 5.25, 4.0, 3.0, 1.75, 2.0, 2.25, 4.0, 4.0, 4.0, 5.5, 4.75, 3.25, 3.0, 2.25, 1.25, 2.75, 5.5, 6.0, 4.75, 3.5, 4.75, 2.25, 4.5, 5.25, 5.5, 3.75, 4.25, 2.0, 1.75, 2.25, 2.25, 2.25, 4.5, 5.5, 4.5, 4.0, 5.0, 2.5, 2.5, 1.5, 2.5, 2.5, 3.0, 4.75, 2.75, 3.5, 4.5]
# arrX2= [6.5, 6.5, 5.25, 5.25, 4.0, 3.0, 1.75, 2.0, 2.25, 4.0, 4.0, 4.0, 5.5, 4.75, 3.25, 3.0, 2.25, 1.25, 2.75, 5.5, 6.0, 4.75, 3.5, 4.75, 2.25, 4.5, 5.25, 5.5, 3.75, 4.25, 2.0, 1.75, 2.25, 2.25, 2.25, 4.5, 5.5, 4.5, 4.0, 5.0, 2.5, 2.5, 1.5, 2.5, 2.5, 3.0, 4.75, 2.75, 3.5, 4.5]
